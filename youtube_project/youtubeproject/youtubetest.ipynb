# %%
from googleapiclient.discovery import build
import googleapiclient.discovery
import json
import pymongo
import psycopg2
import pandas as pd
import numpy as np
import streamlit as st
from datetime import datetime
import re
from sqlalchemy import Column, Integer, String, TIMESTAMP 
from cryptography.x509 import load_der_x509_certificate
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
from ipykernel import kernelapp as app
from datetime import datetime

# %%
# Api key details 
# creating a function for Api_details

def Api_connect():
    api_key = "AIzaSyA4Xkqss0doi6-eIrH6DGhhticzIQPV51w"

    api_service_name = "youtube"
    api_version = "v3"

    youtube = build(api_service_name,api_version,developerKey=api_key)

    return youtube

youtube = Api_connect()

# %%
youtube

# %%
request = youtube.channels().list(
          part = "snippet,ContentDetails,statistics",
          id="UCoC4TYHD1zDUYGmY59_5LCQ"
)

response = request.execute()

# %%
response
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'q5Yq6d8AJTL_DhbjMMQ6XQvMOu4',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'peKQm1cHgbq5cqKYwSiaP49r7nw',
#    'id': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'snippet': {'title': 'BlackSheep Productions, Ranchi',
#     'description': '',
#     'customUrl': '@blacksheepproductionsranchi',
#     'publishedAt': '2017-05-04T14:39:01Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/XMW2gbY1RkbNY9B6Hi5unHEC0xelpKy5UaTHBGd6zLSb9nZddBQhJmSz7nAr6baawqk-XgpmBBc=s88-c-k-c0x00ffffff-no-rj',
#       'width': 88,
#       'height': 88},
#      'medium': {'url': 'https://yt3.ggpht.com/XMW2gbY1RkbNY9B6Hi5unHEC0xelpKy5UaTHBGd6zLSb9nZddBQhJmSz7nAr6baawqk-XgpmBBc=s240-c-k-c0x00ffffff-no-rj',
#       'width': 240,
#       'height': 240},
#      'high': {'url': 'https://yt3.ggpht.com/XMW2gbY1RkbNY9B6Hi5unHEC0xelpKy5UaTHBGd6zLSb9nZddBQhJmSz7nAr6baawqk-XgpmBBc=s800-c-k-c0x00ffffff-no-rj',
#       'width': 800,
#       'height': 800}},
#     'localized': {'title': 'BlackSheep Productions, Ranchi',
#      'description': ''},
#     'country': 'IN'},
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UUoC4TYHD1zDUYGmY59_5LCQ'}},
#    'statistics': {'viewCount': '8320307',
#     'subscriberCount': '45600',
#     'hiddenSubscriberCount': False,
#     'videoCount': '56'}}]}

# %%
response['items'][0]['contentDetails']['relatedPlaylists']['uploads']
# Out:
# 'UUoC4TYHD1zDUYGmY59_5LCQ'

# %%
response['items'][0]['statistics']
# Out:
# {'viewCount': '8234523',
#  'subscriberCount': '45400',
#  'hiddenSubscriberCount': False,
#  'videoCount': '55'}

# %%
response['items'][0]['snippet']
# Out:
# {'title': 'BlackSheep Productions, Ranchi',
#  'description': '',
#  'customUrl': '@blacksheepproductionsranchi',
#  'publishedAt': '2017-05-04T14:39:01Z',
#  'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/XMW2gbY1RkbNY9B6Hi5unHEC0xelpKy5UaTHBGd6zLSb9nZddBQhJmSz7nAr6baawqk-XgpmBBc=s88-c-k-c0x00ffffff-no-rj',
#    'width': 88,
#    'height': 88},
#   'medium': {'url': 'https://yt3.ggpht.com/XMW2gbY1RkbNY9B6Hi5unHEC0xelpKy5UaTHBGd6zLSb9nZddBQhJmSz7nAr6baawqk-XgpmBBc=s240-c-k-c0x00ffffff-no-rj',
#    'width': 240,
#    'height': 240},
#   'high': {'url': 'https://yt3.ggpht.com/XMW2gbY1RkbNY9B6Hi5unHEC0xelpKy5UaTHBGd6zLSb9nZddBQhJmSz7nAr6baawqk-XgpmBBc=s800-c-k-c0x00ffffff-no-rj',
#    'width': 800,
#    'height': 800}},
#  'localized': {'title': 'BlackSheep Productions, Ranchi', 'description': ''},
#  'country': 'IN'}

# %%
# get channels info
def get_channel_info(channel_id):

    request=youtube.channels().list(
                     part = "snippet,ContentDetails,statistics",
                     id = channel_id
    )
    response=request.execute()

    channel_data = []

    for item in response['items']:
        data = dict(Channel_Name = item ['snippet']['title'],
                Channel_Id = item ['id'],
                Subscribers = item ['statistics']['subscriberCount'],
                Views = item ['statistics']['viewCount'],
                Total_videos = item ['statistics']['videoCount'],
                Channel_Discription = item ['snippet']['description'],
                Playlist_Id  = item ['contentDetails']['relatedPlaylists']['uploads'])
        
        channel_data.append(data)
    
    return data

# %%
Channel_details = get_channel_info("UCPyrIv-3woyRXZozX_8UjAQ")

# %%
Channel_details
# Out:
# {'Channel_Name': '4degreesoffreedom',
#  'Channel_Id': 'UCPyrIv-3woyRXZozX_8UjAQ',
#  'Subscribers': '80',
#  'Views': '18483',
#  'Total_videos': '27',
#  'Channel_Discription': 'funk metal, rap core band 4rm RANCHI....',
#  'Playlist_Id': 'UUPyrIv-3woyRXZozX_8UjAQ'}

# %%
# getting videos ids

def get_videos_ids(channel_id):
    video_ids=[]
    response = youtube.channels().list(id=channel_id,
                                       part = 'contentDetails').execute()
    Playlist_Id = response['items'][0]['contentDetails']['relatedPlaylists']['uploads']

    next_page_token = None

    while True:
        response1 = youtube.playlistItems().list(
                                            part = 'snippet',
                                            playlistId = Playlist_Id,
                                            maxResults=50,
                                            pageToken = next_page_token).execute()
        for i in range(len(response1['items'])):
            video_ids.append(response1['items'][i]['snippet']['resourceId']['videoId'])
        next_page_token = response1.get('nextPageToken')

        if next_page_token is None:
            break
    return video_ids

# %%
Video_ids = get_videos_ids("UCPyrIv-3woyRXZozX_8UjAQ")

# %%
Video_ids
# Out:
# ['W2BIHF1ywRU',
#  '_Ps3G_igyns',
#  'pnt246Nti3c',
#  'tr_pe1XB-Mc',
#  'P7fQgOdmNg8',
#  '12GQ74RU2Ko',
#  'RS6V5uJv8lU',
#  'qeu0FBJyGlQ',
#  'M3YdW1FRUFo',
#  'gNF4bQxoXkQ',
#  'KQbJ9E0XAqc',
#  'ETmI1Fg-Lro',
#  'aRJA0W5tS-M',
#  'ynnozBtLhiE',
#  'WDM0KRjkugU',
#  'GkDpu4seEFk',
#  'yVJ6-WqmaLQ',
#  'OjLb1-mAs2g',
#  'BO3L39fOeH0',
#  'Oo2gKXPwvJk',
#  'Strsql7gFCA',
#  'KemIiwuBpH0',
#  'DSO5sbiS9I8',
#  'pHoWD8nY0SE',
#  'smrUeQENifQ',
#  'YH1OxkAIFns',
#  'cpbIsMTYlxM']

# %%
# getting video information

def get_video_info(Video_ids):
        video_data = []
        for video_id in Video_ids:
            request = youtube.videos().list(
                    part = "snippet,ContentDetails,statistics",
                    id = video_id
            )
            response = request.execute()
        
            for item in response['items']:
                data = dict(Channel_Name = item['snippet']['channelTitle'],
                            Channel_Id = item['snippet']['channelId'],
                            Video_Id = item['id'],
                            Title = item['snippet']['title'],
                            Tags = item['snippet'].get('tags'),
                            Thumbnail = item['snippet']['thumbnails']['default']['url'],
                            Description = item['snippet'].get('description'),
                            Published_Date = item['snippet']['publishedAt'],
                            Duration = item['contentDetails']['duration'],
                            Views = item['statistics'].get('viewCount'),
                            Comments = item['statistics'].get('CommentCount'), 
                            likes = item['statistics'].get('likeCount'),
                            Favorite_Count = item['statistics']['favoriteCount'],
                            Definition = item['contentDetails']['definition'],
                            Caption_Status = item['contentDetails']['caption'])
        
                video_data.append(data)
        return video_data

# %%
video_details = get_video_info(Video_ids)

# %%
video_details
# Out:
# [{'Channel_Name': '4degreesoffreedom',
#   'Channel_Id': 'UCPyrIv-3woyRXZozX_8UjAQ',
#   'Video_Id': 'W2BIHF1ywRU',
#   'Title': 'Gagged (All Power To The People)',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/W2BIHF1ywRU/default.jpg',
#   'Description': 'MTV Indies Chapter 1',
#   'Published_Date': '2017-03-01T13:49:57Z',
#   'Duration': 'PT4M16S',
#   'Views': '998',
#   'Comments': None,
#   'likes': '18',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': '4degreesoffreedom',
#   'Channel_Id': 'UCPyrIv-3woyRXZozX_8UjAQ',
#   'Video_Id': '_Ps3G_igyns',
#   'Title': '4 DEGREES OF FREEDOM LIVE AT  IIT CHENNAI SAARANG PRELIMS(BANGALORE LEG) 2014',
#   'Tags': ['Rapcore (Musical Genre)',
#    'saarang iit chennai bangalore',
#    'Metalcore (Musical Genre)',
#    'Indian Institute Of Technology Madras (College/University)',
#    'Saarang',
#    'Chennai (Indian City)',
#    'College (TV Genre)',
#    'Ranchi (Indian City)',
#    'Indian Institutes Of Technology (Educational Institution)',
#    'bandwagon'],
#   'Thumbnail': 'https://i.ytimg.com/vi/_Ps3G_igyns/default.jpg',
#   'Description': '4 DEGREES OF FREEDOM LIVE AT  IIT CHENNAI SAARANG PRELIMS(BANGALORE LEG) 2014',
#   'Published_Date': '2015-08-15T20:10:42Z',
#   'Duration': 'PT3M33S',
#   'Views': '877',
#   'Comments': None,
#   'likes': '8',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': '4degreesoffreedom',
#   'Channel_Id': 'UCPyrIv-3woyRXZozX_8UjAQ',
#   'Video_Id': 'pnt246Nti3c',
#   'Title': '4 degrees of freedom-gagged live at DETOX 2014',
#   'Tags': ['Rapcore (Musical Genre)',
#    'Alternative Rock (Musical Genre)',
#    'Electronica (Musical Genre)',
#    'Metalcore (Musical Genre)',
#    'Ranchi (Indian City)'],
#   'Thumbnail': 'https://i.ytimg.com/vi/pnt246Nti3c/default.jpg',
#   'Description': '4 degrees of freedom-gagged live at DETOX 2014',
#   'Published_Date': '2014-10-19T12:24:47Z',
#   'Duration': 'PT4M47S',
#   'Views': '1949',
#   'Comments': None,
#   'likes': '24',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': '4degreesoffreedom',
#   'Channel_Id': 'UCPyrIv-3woyRXZozX_8UjAQ',
#   'Video_Id': 'tr_pe1XB-Mc',
#   'Title': '4 DEGREES OF FREEDOM LIVE AT HORNBILL INTERNATIONAL FINALS 2013- ECHOES OF THE VALLEY',
#   'Tags': ['Metalcore (Musical Genre)',
#    'Alternative Rock (Musical Genre)',
#    'Rapcore (Musical Genre)',
#    'Electronica (Musical Genre)',
#    'Degrees Of Freedom',
#    'Festival (Type Of Conference)'],
#   'Thumbnail': 'https://i.ytimg.com/vi/tr_pe1XB-Mc/default.jpg',
#   'Description': '4 DEGREES OF FREEDOM LIVE AT HORNBILL INTERNATIONAL FINALS 2013 - ECHOES OF THE VALLEY',
#   'Published_Date': '2014-10-19T10:20:41Z',
#   'Duration': 'PT5M27S',
#   'Views': '3383',
#   'Comments': None,
#   'likes': '50',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': '4degreesoffreedom',
#   'Channel_Id': 'UCPyrIv-3woyRXZozX_8UjAQ',
#   'Video_Id': 'P7fQgOdmNg8',
#   'Title': '4 DEGREES OF FREEDOM LIVE AT IIT GUWAHATI, PRELIMS-THE REVOLUTION WILL NOT BE TELEVISED',
#   'Tags': ['Indian Institutes Of Technology (Organization)'],
#   'Thumbnail': 'https://i.ytimg.com/vi/P7fQgOdmNg8/default.jpg',
#   'Description': '4 DEGREES OF FREEDOM LIVE AT IIT GUWAHATI, PRELIMS-THE REVOLUTION WILL NOT BE TELEVISED',
#   'Published_Date': '2014-04-09T19:14:13Z',
#   'Duration': 'PT4M9S',
#   'Views': '655',
#   'Comments': None,
#   'likes': '12',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': '4degreesoffreedom',
#   'Channel_Id': 'UCPyrIv-3woyRXZozX_8UjAQ',
#   'Video_Id': '12GQ74RU2Ko',
#   'Title': '4 DEGREES OF FREEDOM LIVE AT IIT GUWAHATI ALCHERINGA PRELIMS- GAGGED',
#   'Tags': ['Indian Institutes Of Technology (Organization)',
#    'Guwahati (City/Town/Village)'],
#   'Thumbnail': 'https://i.ytimg.com/vi/12GQ74RU2Ko/default.jpg',
#   'Description': '4 DEGREES OF FREEDOM LIVE AT IIT GUWAHATI ALCHERINGA PRELIMS- GAGGED',
#   'Published_Date': '2014-04-09T18:07:48Z',
#   'Duration': 'PT4M36S',
#   'Views': '713',
#   'Comments': None,
#   'likes': '10',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': '4degreesoffreedom',
#   'Channel_Id': 'UCPyrIv-3woyRXZozX_8UjAQ',
#   'Video_Id': 'RS6V5uJv8lU',
#   'Title': '4 degrees of freedom live at dox xavier school fest 2012(main angle)',
#   'Tags': ['Festival', 'Capture', 'School', 'Live', 'Live (band)'],
#   'Thumbnail': 'https://i.ytimg.com/vi/RS6V5uJv8lU/default.jpg',
#   'Description': 'headlining act.........',
#   'Published_Date': '2013-04-06T14:10:52Z',
#   'Duration': 'PT15M36S',
#   'Views': '1079',
#   'Comments': None,
#   'likes': '11',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': '4degreesoffreedom',
#   'Channel_Id': 'UCPyrIv-3woyRXZozX_8UjAQ',
#   'Video_Id': 'qeu0FBJyGlQ',
#   'Title': '4 DEGREES OF FREEDOM LIVE@ BIT SINDRI- FREEDOM',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/qeu0FBJyGlQ/default.jpg',
#   'Description': ' ',
#   'Published_Date': '2013-03-24T09:54:09Z',
#   'Duration': 'PT5M52S',
#   'Views': '479',
#   'Comments': None,
#   'likes': '10',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': '4degreesoffreedom',
#   'Channel_Id': 'UCPyrIv-3woyRXZozX_8UjAQ',
#   'Video_Id': 'M3YdW1FRUFo',
#   'Title': '4 DEGREES OF FREEDOM LIVE AT DOX,2012(CROWD ANGLE)',
#   'Tags': ['Live', 'Performance', 'Band', 'Stage', 'Live (band)'],
#   'Thumbnail': 'https://i.ytimg.com/vi/M3YdW1FRUFo/default.jpg',
#   'Description': '4 DEGREES OF FREEDOM LIVE AT DOX fest,xavier school,,2012(CROWD ANGLE)........sound aint gud...bt chk out d crowd',
#   'Published_Date': '2013-03-22T07:31:57Z',
#   'Duration': 'PT3M15S',
#   'Views': '212',
#   'Comments': None,
#   'likes': '3',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': '4degreesoffreedom',
#   'Channel_Id': 'UCPyrIv-3woyRXZozX_8UjAQ',
#   'Video_Id': 'gNF4bQxoXkQ',
#   'Title': '4 degrees of freedom live at st.xaviers college fest 2012',
#   'Tags': ['College (TV Genre)',
#    'Live',
#    'Fest',
#    'Concert',
#    'Live (band)',
#    'University',
#    'Band'],
#   'Thumbnail': 'https://i.ytimg.com/vi/gNF4bQxoXkQ/default.jpg',
#   'Description': '4 degrees of freedom live at st.xaviers college fest 2012',
#   'Published_Date': '2012-08-25T13:19:05Z',
#   'Duration': 'PT3M49S',
#   'Views': '1224',
#   'Comments': None,
#   'likes': '17',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': '4degreesoffreedom',
#   'Channel_Id': 'UCPyrIv-3woyRXZozX_8UjAQ',
#   'Video_Id': 'KQbJ9E0XAqc',
#   'Title': '4 DEGREES OF FREEDOM-LOVE REVOLUTION LIVE@WYAMSHALA GROUNDS.mp4',
#   'Tags': ['Revolution (Field Of Study)', 'College', 'Ground', 'University'],
#   'Thumbnail': 'https://i.ytimg.com/vi/KQbJ9E0XAqc/default.jpg',
#   'Description': '4 DEGREES OF FREEDOM-LOVE REVOLUTION LIVE@WYAMSHALA GROUNDS',
#   'Published_Date': '2012-05-02T07:02:01Z',
#   'Duration': 'PT3M35S',
#   'Views': '93',
#   'Comments': None,
#   'likes': '1',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': '4degreesoffreedom',
#   'Channel_Id': 'UCPyrIv-3woyRXZozX_8UjAQ',
#   'Video_Id': 'ETmI1Fg-Lro',
#   'Title': '4 DEGREES OF FREEDOM LIVE 34th NATIONAL GAMES- ECHOES OF D VALLEY.flv',
#   'Tags': ['music',
#    'live music',
#    'Performance',
#    'Concert (TV Genre)',
#    'Game',
#    'Valley',
#    'Stage'],
#   'Thumbnail': 'https://i.ytimg.com/vi/ETmI1Fg-Lro/default.jpg',
#   'Description': '4 DEGREES OF FREEDOM LIVE 34th NATIONAL GAMES- ECHOES OF D VALLEY',
#   'Published_Date': '2012-04-20T07:40:28Z',
#   'Duration': 'PT5M34S',
#   'Views': '758',
#   'Comments': None,
#   'likes': '5',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': '4degreesoffreedom',
#   'Channel_Id': 'UCPyrIv-3woyRXZozX_8UjAQ',
#   'Video_Id': 'aRJA0W5tS-M',
#   'Title': '4 DEGREES OF FREEDOM LIVE@ XAVIER INSTITUTE OF MANAGEMENT, BHUBHANESHWAR.mp4',
#   'Tags': ['GigLive', 'Part', 'Performance'],
#   'Thumbnail': 'https://i.ytimg.com/vi/aRJA0W5tS-M/default.jpg',
#   'Description': '4 DEGREES OF FREEDOM LIVE@ XIM BHUBHANESHWAR',
#   'Published_Date': '2012-04-14T10:21:18Z',
#   'Duration': 'PT2M27S',
#   'Views': '147',
#   'Comments': None,
#   'likes': '6',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': '4degreesoffreedom',
#   'Channel_Id': 'UCPyrIv-3woyRXZozX_8UjAQ',
#   'Video_Id': 'ynnozBtLhiE',
#   'Title': '4 DEGREES OF FREEDOM LIVE@ NIT JAMSHEDPUR- GRASS.avi',
#   'Tags': ['Mpeg4',
#    'Avi',
#    'Clip1',
#    'X264',
#    'Mpeg2video',
#    'Player',
#    'Mp4',
#    'Upload',
#    'music',
#    'live concert',
#    'rock music',
#    'live music',
#    'MPEG-4 Part 14 (File Format)',
#    'Youtube',
#    'H264'],
#   'Thumbnail': 'https://i.ytimg.com/vi/ynnozBtLhiE/default.jpg',
#   'Description': '4 DEGREES OF FREEDOM LIVE@ NIT JAMSHEDPUR- GRASS',
#   'Published_Date': '2012-04-10T07:53:35Z',
#   'Duration': 'PT1M56S',
#   'Views': '341',
#   'Comments': None,
#   'likes': '2',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': '4degreesoffreedom',
#   'Channel_Id': 'UCPyrIv-3woyRXZozX_8UjAQ',
#   'Video_Id': 'WDM0KRjkugU',
#   'Title': '4 DEGREES OF FREEDOM LIVE@ 34th NATIONAL GAMES-DEATH OF A NATION.flv',
#   'Tags': ['National', 'Game', 'Games', 'Anthem', 'Hendrix'],
#   'Thumbnail': 'https://i.ytimg.com/vi/WDM0KRjkugU/default.jpg',
#   'Description': '4 DEGREES OF FREEDOM LIVE@ 34th NATIONAL GAMES-DEATH OF A NATION',
#   'Published_Date': '2012-04-09T14:17:39Z',
#   'Duration': 'PT3M15S',
#   'Views': '759',
#   'Comments': None,
#   'likes': '9',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': '4degreesoffreedom',
#   'Channel_Id': 'UCPyrIv-3woyRXZozX_8UjAQ',
#   'Video_Id': 'GkDpu4seEFk',
#   'Title': '4 DEGREES OF FREEDOM- 88 LIVE@BIT MESRA(MORELLOS MOSHPIT).mp4',
#   'Tags': ['4',
#    'DEGREES',
#    'OF',
#    'FREEDOM',
#    '88',
#    'LIVE@BIT',
#    'MESRAMORELLOS',
#    'MOSHPIT'],
#   'Thumbnail': 'https://i.ytimg.com/vi/GkDpu4seEFk/default.jpg',
#   'Description': '4 DEGREES OF FREEDOM- 88 LIVE@BIT MESRA(MORELLOS MOSHPIT)',
#   'Published_Date': '2012-04-09T13:48:16Z',
#   'Duration': 'PT3M12S',
#   'Views': '979',
#   'Comments': None,
#   'likes': '15',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': '4degreesoffreedom',
#   'Channel_Id': 'UCPyrIv-3woyRXZozX_8UjAQ',
#   'Video_Id': 'yVJ6-WqmaLQ',
#   'Title': '4 Degrees of freedom live@ NIT ROURKELA!!.mp4',
#   'Tags': ['Youtube',
#    'Mp4',
#    'Mpeg',
#    'Upload',
#    'Avi',
#    'Media',
#    'Improved',
#    'Live (band)',
#    'Concert',
#    'MPEG-4 Part 14'],
#   'Thumbnail': 'https://i.ytimg.com/vi/yVJ6-WqmaLQ/default.jpg',
#   'Description': '4 Degrees of freedom live@ NIT ROURKELA!!',
#   'Published_Date': '2012-03-18T10:55:19Z',
#   'Duration': 'PT15M19S',
#   'Views': '1585',
#   'Comments': None,
#   'likes': '13',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': '4degreesoffreedom',
#   'Channel_Id': 'UCPyrIv-3woyRXZozX_8UjAQ',
#   'Video_Id': 'OjLb1-mAs2g',
#   'Title': '4 DEGREES OF FREEDOM FEAT  ZUBIN EKKA AND AMIT RAY LIVE@ PUB ROCK FEST JSR',
#   'Tags': ['4',
#    'DEGREES',
#    'OF',
#    'FREEDOM',
#    'FEAT',
#    'ZUBIN',
#    'EKKA',
#    'AND',
#    'AMIT',
#    'RAY',
#    'LIVE@',
#    'PUB',
#    'ROCK',
#    'FEST',
#    'JSR'],
#   'Thumbnail': 'https://i.ytimg.com/vi/OjLb1-mAs2g/default.jpg',
#   'Description': ' ',
#   'Published_Date': '2012-02-26T22:47:51Z',
#   'Duration': 'PT5M36S',
#   'Views': '231',
#   'Comments': None,
#   'likes': '4',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': '4degreesoffreedom',
#   'Channel_Id': 'UCPyrIv-3woyRXZozX_8UjAQ',
#   'Video_Id': 'BO3L39fOeH0',
#   'Title': '4 DEGREES OF FREEDOM-BREAKDOWN LIVE@BIT SINDRI.mpg',
#   'Tags': ['Day', 'Bit', 'Avi', 'Mpeg4'],
#   'Thumbnail': 'https://i.ytimg.com/vi/BO3L39fOeH0/default.jpg',
#   'Description': '4 DEGREES OF FREEDOM-BREAKDOWN LIVE@BIT SINDRI',
#   'Published_Date': '2012-02-25T22:13:15Z',
#   'Duration': 'PT3M32S',
#   'Views': '208',
#   'Comments': None,
#   'likes': '2',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': '4degreesoffreedom',
#   'Channel_Id': 'UCPyrIv-3woyRXZozX_8UjAQ',
#   'Video_Id': 'Oo2gKXPwvJk',
#   'Title': '4 DEGREES OF FREEDOM LIVE@ WYAMSHALA GROUNDS.flv',
#   'Tags': ['Live (band)', 'Musical Ensemble', 'Concert', 'Ground', 'Theatre'],
#   'Thumbnail': 'https://i.ytimg.com/vi/Oo2gKXPwvJk/default.jpg',
#   'Description': '4 DEGREES OF FREEDOM LIVE@ WYAMSHALA GROUNDS.flv',
#   'Published_Date': '2012-02-17T09:01:00Z',
#   'Duration': 'PT4M7S',
#   'Views': '86',
#   'Comments': None,
#   'likes': '2',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': '4degreesoffreedom',
#   'Channel_Id': 'UCPyrIv-3woyRXZozX_8UjAQ',
#   'Video_Id': 'Strsql7gFCA',
#   'Title': '4 DEGREES OF FREEDOM LIVE@ PUB ROCK FEST,GANGA REGENCY , JAMSHEDPUR.flv',
#   'Tags': ['Live (band)', 'Festival', 'Concert', 'Musical Ensemble', 'None'],
#   'Thumbnail': 'https://i.ytimg.com/vi/Strsql7gFCA/default.jpg',
#   'Description': '4 DEGREES OF FREEDOM LIVE@ PUB ROCK FEST,GANGA REGENCY , JAMSHEDPUR.flv',
#   'Published_Date': '2012-02-17T08:43:45Z',
#   'Duration': 'PT2M33S',
#   'Views': '299',
#   'Comments': None,
#   'likes': '6',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': '4degreesoffreedom',
#   'Channel_Id': 'UCPyrIv-3woyRXZozX_8UjAQ',
#   'Video_Id': 'KemIiwuBpH0',
#   'Title': '4 DEGREES OF FREEDOM- CRIMSON TIDE LIVE @ PUB ROCK FEST , GANGA REGENCY , JAMSHEDPUR.flv',
#   'Tags': ['Live (band)', 'Fest', 'Concert'],
#   'Thumbnail': 'https://i.ytimg.com/vi/KemIiwuBpH0/default.jpg',
#   'Description': '4 DEGREES OF FREEDOM- CRIMSON TIDE LIVE @ PUB ROCK FEST , GANGA REGENCY , JAMSHEDPUR.flv',
#   'Published_Date': '2012-02-17T08:17:45Z',
#   'Duration': 'PT3M8S',
#   'Views': '130',
#   'Comments': None,
#   'likes': '2',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': '4degreesoffreedom',
#   'Channel_Id': 'UCPyrIv-3woyRXZozX_8UjAQ',
#   'Video_Id': 'DSO5sbiS9I8',
#   'Title': '4 DEGREES OF FREEDOM(Morellos moshpit)-FREEDOM LIVE @ IIT KHARAGHPUR SPRING FEST 2010.MPG',
#   'Tags': ['Live (band)',
#    'Spring',
#    'Fest',
#    'Concert',
#    'Festival',
#    'Gig',
#    'Live Concert'],
#   'Thumbnail': 'https://i.ytimg.com/vi/DSO5sbiS9I8/default.jpg',
#   'Description': '4 DEGREES OF FREEDOM(Morellos moshpit)-FREEDOM LIVE @ IIT KHARAGHPUR SPRING FEST 2010.MPG',
#   'Published_Date': '2012-02-15T09:27:19Z',
#   'Duration': 'PT1M20S',
#   'Views': '248',
#   'Comments': None,
#   'likes': '3',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': '4degreesoffreedom',
#   'Channel_Id': 'UCPyrIv-3woyRXZozX_8UjAQ',
#   'Video_Id': 'pHoWD8nY0SE',
#   'Title': '4 DEGREES OF FREEDOM(morellos moshpit) LIVE@IIT KHARAGHPUR SPRING FEST 2010.MPG',
#   'Tags': ['Spring', 'Fest', 'India', 'Live', 'Concert', 'Festival'],
#   'Thumbnail': 'https://i.ytimg.com/vi/pHoWD8nY0SE/default.jpg',
#   'Description': '4 DEGREES OF FREEDOM(morellos moshpit) LIVE@IIT KHARAGHPUR SPRING FEST 2010',
#   'Published_Date': '2012-02-06T10:02:26Z',
#   'Duration': 'PT2M30S',
#   'Views': '260',
#   'Comments': None,
#   'likes': '4',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': '4degreesoffreedom',
#   'Channel_Id': 'UCPyrIv-3woyRXZozX_8UjAQ',
#   'Video_Id': 'smrUeQENifQ',
#   'Title': '4 DEGREES OF FREEDOM- REVOLUTION WILL NOT BE TELEVISED LIVE@ UNSEEN UNDERGROUND,CHENNAI!!!!',
#   'Tags': ['Live (band)',
#    'Revolution',
#    'Concert',
#    'Performance',
#    'music',
#    'live concert',
#    'live music',
#    'Live Performance',
#    'Stage'],
#   'Thumbnail': 'https://i.ytimg.com/vi/smrUeQENifQ/default.jpg',
#   'Description': '4 DEGREES OF FREEDOM- REVOLUTION WILL NOT BE TELEVISED LIVE@ UNSEEN UNDERGROUND,CHENNAI!!!!',
#   'Published_Date': '2012-02-06T05:51:41Z',
#   'Duration': 'PT3M54S',
#   'Views': '178',
#   'Comments': None,
#   'likes': '5',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': '4degreesoffreedom',
#   'Channel_Id': 'UCPyrIv-3woyRXZozX_8UjAQ',
#   'Video_Id': 'YH1OxkAIFns',
#   'Title': "4 DEGREES OF FREEDOM - PAP's(project affected people) LIVE@ UNSEEN UNDERGROUND,CHENNAI",
#   'Tags': ['Live (band)',
#    'rock music',
#    'live music',
#    'Rock Music',
#    'Alternative',
#    'Garage',
#    'live concert',
#    'Gig'],
#   'Thumbnail': 'https://i.ytimg.com/vi/YH1OxkAIFns/default.jpg',
#   'Description': "4 DEGREES OF FREEDOM - PAP's(project affected people) LIVE@ UNSEEN UNDERGROUND,CHENNAI",
#   'Published_Date': '2012-02-06T05:34:56Z',
#   'Duration': 'PT3M47S',
#   'Views': '293',
#   'Comments': None,
#   'likes': '3',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': '4degreesoffreedom',
#   'Channel_Id': 'UCPyrIv-3woyRXZozX_8UjAQ',
#   'Video_Id': 'cpbIsMTYlxM',
#   'Title': '4 DEGREES OF FREEDOM PHOTO SYNC.wmv',
#   'Tags': ['4', 'DEGREES', 'OF', 'FREEDOM', 'PHOTO', 'SYNC'],
#   'Thumbnail': 'https://i.ytimg.com/vi/cpbIsMTYlxM/default.jpg',
#   'Description': '4 degrees of freedom photo sync',
#   'Published_Date': '2012-02-05T07:25:55Z',
#   'Duration': 'PT2M47S',
#   'Views': '319',
#   'Comments': None,
#   'likes': '7',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'}]

# %%
# creat funtion for get the comment information
def get_comment_info(Video_ids):
    comment_data = []
    try:
        for video_id in Video_ids:    
            request = youtube.commentThreads().list(
                        part = 'snippet',
                        videoId =video_id,                              #','.join(video_ids[i:i+50]),
                        maxResults = 50)
            
            response = request.execute()
            # adding this code in last moment:

            
            for i in range(len(response['items'])):
                    data =dict(
                                Comment_Id = response['items'][0]['snippet']['topLevelComment']['id'],
                                Video_Id = response['items'][0]['snippet']['topLevelComment']['snippet']['videoId'],
                                Comment_text = response['items'][0]['snippet']['topLevelComment']['snippet']['textDisplay'],
                                Comment_author =response['items'][0]['snippet']['topLevelComment']['snippet'],
                                Comment_published = response['items'][0]['snippet']['topLevelComment']['snippet']['publishedAt'])
                    comment_data.append(data)

            # for item in response['items']:
            #     data=dict(Comment_Id=item['snippet']['topLevelComment']['id'],
            #             Video_Id=item['snippet']['topLevelComment']['snippet']['videoId'],
            #             Comment_Text=item['snippet']['topLevelComment']['snippet']['textDisplay'],
            #             Comment_Author=item['snippet']['topLevelComment']['snippet']['authorDisplayName'],
            #             Comment_Published=item['snippet']['topLevelComment']['snippet']['publishedAt'])
                
            #     comment_data.append(data)
         
    except:
        pass        
    return comment_data

# %%
Comment_details = get_comment_info(Video_ids)

# %%
Comment_details
# Out:
# [{'Comment_Id': 'Ugw6vondLlmYD5M8ZUF4AaABAg',
#   'Video_Id': 'tr_pe1XB-Mc',
#   'Comment_text': 'Aren’t you people doing shows now ?',
#   'Comment_author': {'channelId': 'UCPyrIv-3woyRXZozX_8UjAQ',
#    'videoId': 'tr_pe1XB-Mc',
#    'textDisplay': 'Aren’t you people doing shows now ?',
#    'textOriginal': 'Aren’t you people doing shows now ?',
#    'authorDisplayName': '@gamerscontakt1972',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mMjh96JLwjg5pEY7sE3KQOzLjA1-Sy074Vt5JApnNd8wQ=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@gamerscontakt1972',
#    'authorChannelId': {'value': 'UCcPUaAFqZVlGFTIXUx4YXPA'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2024-07-17T14:33:44Z',
#    'updatedAt': '2024-07-17T14:33:44Z'},
#   'Comment_published': '2024-07-17T14:33:44Z'},
#  {'Comment_Id': 'UgztXwf0fjljbd6Bztt4AaABAg',
#   'Video_Id': 'RS6V5uJv8lU',
#   'Comment_text': 'awesome live performance!!!!, 4 degreesoffreedom 4 ever!!!',
#   'Comment_author': {'channelId': 'UCPyrIv-3woyRXZozX_8UjAQ',
#    'videoId': 'RS6V5uJv8lU',
#    'textDisplay': 'awesome live performance!!!!, 4 degreesoffreedom 4 ever!!!',
#    'textOriginal': 'awesome live performance!!!!, 4 degreesoffreedom 4 ever!!!',
#    'authorDisplayName': '@sunnyalas6044',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nVlGkRNKWRioKiz4I0Akcuh5A9poa0_NM6rc1944DnsQ=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@sunnyalas6044',
#    'authorChannelId': {'value': 'UCBbcAf9hXTU1u8C12PQEYUg'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2013-09-22T21:14:40Z',
#    'updatedAt': '1970-01-01T00:00:00Z'},
#   'Comment_published': '2013-09-22T21:14:40Z'},
#  {'Comment_Id': 'UgwKtxHGiT5MVNhvYtl4AaABAg',
#   'Video_Id': 'M3YdW1FRUFo',
#   'Comment_text': 'What about us? We Jharkhand Rock Gigs who advertise all these bands??',
#   'Comment_author': {'channelId': 'UCPyrIv-3woyRXZozX_8UjAQ',
#    'videoId': 'M3YdW1FRUFo',
#    'textDisplay': 'What about us? We Jharkhand Rock Gigs who advertise all these bands??',
#    'textOriginal': 'What about us? We Jharkhand Rock Gigs who advertise all these bands??',
#    'authorDisplayName': '@TarunPaulKachhap',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lh9CrDmKmVNxVNE5uo0bSC6qOTId6pfY_6AxNis_W02tg=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@TarunPaulKachhap',
#    'authorChannelId': {'value': 'UC_pXKWaqoDBM9CLcRA6wl5w'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2013-04-05T02:45:50Z',
#    'updatedAt': '1970-01-01T00:00:00Z'},
#   'Comment_published': '2013-04-05T02:45:50Z'},
#  {'Comment_Id': 'UgwKtxHGiT5MVNhvYtl4AaABAg',
#   'Video_Id': 'M3YdW1FRUFo',
#   'Comment_text': 'What about us? We Jharkhand Rock Gigs who advertise all these bands??',
#   'Comment_author': {'channelId': 'UCPyrIv-3woyRXZozX_8UjAQ',
#    'videoId': 'M3YdW1FRUFo',
#    'textDisplay': 'What about us? We Jharkhand Rock Gigs who advertise all these bands??',
#    'textOriginal': 'What about us? We Jharkhand Rock Gigs who advertise all these bands??',
#    'authorDisplayName': '@TarunPaulKachhap',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lh9CrDmKmVNxVNE5uo0bSC6qOTId6pfY_6AxNis_W02tg=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@TarunPaulKachhap',
#    'authorChannelId': {'value': 'UC_pXKWaqoDBM9CLcRA6wl5w'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2013-04-05T02:45:50Z',
#    'updatedAt': '1970-01-01T00:00:00Z'},
#   'Comment_published': '2013-04-05T02:45:50Z'},
#  {'Comment_Id': 'UgwKtxHGiT5MVNhvYtl4AaABAg',
#   'Video_Id': 'M3YdW1FRUFo',
#   'Comment_text': 'What about us? We Jharkhand Rock Gigs who advertise all these bands??',
#   'Comment_author': {'channelId': 'UCPyrIv-3woyRXZozX_8UjAQ',
#    'videoId': 'M3YdW1FRUFo',
#    'textDisplay': 'What about us? We Jharkhand Rock Gigs who advertise all these bands??',
#    'textOriginal': 'What about us? We Jharkhand Rock Gigs who advertise all these bands??',
#    'authorDisplayName': '@TarunPaulKachhap',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lh9CrDmKmVNxVNE5uo0bSC6qOTId6pfY_6AxNis_W02tg=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@TarunPaulKachhap',
#    'authorChannelId': {'value': 'UC_pXKWaqoDBM9CLcRA6wl5w'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2013-04-05T02:45:50Z',
#    'updatedAt': '1970-01-01T00:00:00Z'},
#   'Comment_published': '2013-04-05T02:45:50Z'},
#  {'Comment_Id': 'UgwKtxHGiT5MVNhvYtl4AaABAg',
#   'Video_Id': 'M3YdW1FRUFo',
#   'Comment_text': 'What about us? We Jharkhand Rock Gigs who advertise all these bands??',
#   'Comment_author': {'channelId': 'UCPyrIv-3woyRXZozX_8UjAQ',
#    'videoId': 'M3YdW1FRUFo',
#    'textDisplay': 'What about us? We Jharkhand Rock Gigs who advertise all these bands??',
#    'textOriginal': 'What about us? We Jharkhand Rock Gigs who advertise all these bands??',
#    'authorDisplayName': '@TarunPaulKachhap',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lh9CrDmKmVNxVNE5uo0bSC6qOTId6pfY_6AxNis_W02tg=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@TarunPaulKachhap',
#    'authorChannelId': {'value': 'UC_pXKWaqoDBM9CLcRA6wl5w'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2013-04-05T02:45:50Z',
#    'updatedAt': '1970-01-01T00:00:00Z'},
#   'Comment_published': '2013-04-05T02:45:50Z'},
#  {'Comment_Id': 'UgxuhXlOy7xwjaIVzfZ4AaABAg',
#   'Video_Id': 'Oo2gKXPwvJk',
#   'Comment_text': 'Mast yaar, 4 degree freedom...but it turned me full 360 degree :-)\n',
#   'Comment_author': {'channelId': 'UCPyrIv-3woyRXZozX_8UjAQ',
#    'videoId': 'Oo2gKXPwvJk',
#    'textDisplay': 'Mast yaar, 4 degree freedom...but it turned me full 360 degree :-)\n',
#    'textOriginal': 'Mast yaar, 4 degree freedom...but it turned me full 360 degree :-)\n',
#    'authorDisplayName': '@smitabernadett',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kLMeTZwV9uXenDkHq4tMoKqHq4J1-3D3bGhjUXIhGxpg=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@smitabernadett',
#    'authorChannelId': {'value': 'UCX8yT3n91sPM2al5H-chLKg'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2012-02-23T14:12:30Z',
#    'updatedAt': '1970-01-01T00:00:00Z'},
#   'Comment_published': '2012-02-23T14:12:30Z'},
#  {'Comment_Id': 'UgxaCrnsUr3mmtk642F4AaABAg',
#   'Video_Id': 'Strsql7gFCA',
#   'Comment_text': 'Wow love this song man\n',
#   'Comment_author': {'channelId': 'UCPyrIv-3woyRXZozX_8UjAQ',
#    'videoId': 'Strsql7gFCA',
#    'textDisplay': 'Wow love this song man\n',
#    'textOriginal': 'Wow love this song man\n',
#    'authorDisplayName': '@java8',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_l8TOGvm-FAKc8bPrZYAEKriQxUzKRkW_jJfXSRiyho4w=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@java8',
#    'authorChannelId': {'value': 'UC0vzHJkMM6y13kRbZ8TOneg'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2012-02-27T01:20:20Z',
#    'updatedAt': '1970-01-01T00:00:00Z'},
#   'Comment_published': '2012-02-27T01:20:20Z'},
#  {'Comment_Id': 'UgxaCrnsUr3mmtk642F4AaABAg',
#   'Video_Id': 'Strsql7gFCA',
#   'Comment_text': 'Wow love this song man\n',
#   'Comment_author': {'channelId': 'UCPyrIv-3woyRXZozX_8UjAQ',
#    'videoId': 'Strsql7gFCA',
#    'textDisplay': 'Wow love this song man\n',
#    'textOriginal': 'Wow love this song man\n',
#    'authorDisplayName': '@java8',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_l8TOGvm-FAKc8bPrZYAEKriQxUzKRkW_jJfXSRiyho4w=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@java8',
#    'authorChannelId': {'value': 'UC0vzHJkMM6y13kRbZ8TOneg'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2012-02-27T01:20:20Z',
#    'updatedAt': '1970-01-01T00:00:00Z'},
#   'Comment_published': '2012-02-27T01:20:20Z'},
#  {'Comment_Id': 'UgxaCrnsUr3mmtk642F4AaABAg',
#   'Video_Id': 'Strsql7gFCA',
#   'Comment_text': 'Wow love this song man\n',
#   'Comment_author': {'channelId': 'UCPyrIv-3woyRXZozX_8UjAQ',
#    'videoId': 'Strsql7gFCA',
#    'textDisplay': 'Wow love this song man\n',
#    'textOriginal': 'Wow love this song man\n',
#    'authorDisplayName': '@java8',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_l8TOGvm-FAKc8bPrZYAEKriQxUzKRkW_jJfXSRiyho4w=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@java8',
#    'authorChannelId': {'value': 'UC0vzHJkMM6y13kRbZ8TOneg'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2012-02-27T01:20:20Z',
#    'updatedAt': '1970-01-01T00:00:00Z'},
#   'Comment_published': '2012-02-27T01:20:20Z'},
#  {'Comment_Id': 'UgwOwyFUpcb3m_4io7x4AaABAg',
#   'Video_Id': 'DSO5sbiS9I8',
#   'Comment_text': 'Thanx smita',
#   'Comment_author': {'channelId': 'UCPyrIv-3woyRXZozX_8UjAQ',
#    'videoId': 'DSO5sbiS9I8',
#    'textDisplay': 'Thanx smita',
#    'textOriginal': 'Thanx smita',
#    'authorDisplayName': '@4degreesoffreedom',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kpOidYzHhv0_Yi1G4UZ8-Oe69y5Q1KY3ILc0_qC5Ttkk8=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@4degreesoffreedom',
#    'authorChannelId': {'value': 'UCPyrIv-3woyRXZozX_8UjAQ'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2012-02-23T18:26:11Z',
#    'updatedAt': '1970-01-01T00:00:00Z'},
#   'Comment_published': '2012-02-23T18:26:11Z'},
#  {'Comment_Id': 'UgwOwyFUpcb3m_4io7x4AaABAg',
#   'Video_Id': 'DSO5sbiS9I8',
#   'Comment_text': 'Thanx smita',
#   'Comment_author': {'channelId': 'UCPyrIv-3woyRXZozX_8UjAQ',
#    'videoId': 'DSO5sbiS9I8',
#    'textDisplay': 'Thanx smita',
#    'textOriginal': 'Thanx smita',
#    'authorDisplayName': '@4degreesoffreedom',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kpOidYzHhv0_Yi1G4UZ8-Oe69y5Q1KY3ILc0_qC5Ttkk8=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@4degreesoffreedom',
#    'authorChannelId': {'value': 'UCPyrIv-3woyRXZozX_8UjAQ'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2012-02-23T18:26:11Z',
#    'updatedAt': '1970-01-01T00:00:00Z'},
#   'Comment_published': '2012-02-23T18:26:11Z'},
#  {'Comment_Id': 'UgyYnOli7DV44YfczUZ4AaABAg',
#   'Video_Id': 'pHoWD8nY0SE',
#   'Comment_text': 'Serch 4 us on facebuk n stay updated! Thanx 4 likng our songs!',
#   'Comment_author': {'channelId': 'UCPyrIv-3woyRXZozX_8UjAQ',
#    'videoId': 'pHoWD8nY0SE',
#    'textDisplay': 'Serch 4 us on facebuk n stay updated! Thanx 4 likng our songs!',
#    'textOriginal': 'Serch 4 us on facebuk n stay updated! Thanx 4 likng our songs!',
#    'authorDisplayName': '@4degreesoffreedom',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kpOidYzHhv0_Yi1G4UZ8-Oe69y5Q1KY3ILc0_qC5Ttkk8=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@4degreesoffreedom',
#    'authorChannelId': {'value': 'UCPyrIv-3woyRXZozX_8UjAQ'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2012-02-23T18:12:16Z',
#    'updatedAt': '1970-01-01T00:00:00Z'},
#   'Comment_published': '2012-02-23T18:12:16Z'},
#  {'Comment_Id': 'UgyYnOli7DV44YfczUZ4AaABAg',
#   'Video_Id': 'pHoWD8nY0SE',
#   'Comment_text': 'Serch 4 us on facebuk n stay updated! Thanx 4 likng our songs!',
#   'Comment_author': {'channelId': 'UCPyrIv-3woyRXZozX_8UjAQ',
#    'videoId': 'pHoWD8nY0SE',
#    'textDisplay': 'Serch 4 us on facebuk n stay updated! Thanx 4 likng our songs!',
#    'textOriginal': 'Serch 4 us on facebuk n stay updated! Thanx 4 likng our songs!',
#    'authorDisplayName': '@4degreesoffreedom',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kpOidYzHhv0_Yi1G4UZ8-Oe69y5Q1KY3ILc0_qC5Ttkk8=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@4degreesoffreedom',
#    'authorChannelId': {'value': 'UCPyrIv-3woyRXZozX_8UjAQ'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2012-02-23T18:12:16Z',
#    'updatedAt': '1970-01-01T00:00:00Z'},
#   'Comment_published': '2012-02-23T18:12:16Z'},
#  {'Comment_Id': 'UgyfAp3RbPWC-xHtI2B4AaABAg',
#   'Video_Id': 'YH1OxkAIFns',
#   'Comment_text': 'D SOUND QUALITY IS FUKD UP BUT STILL U LL LUV IT!!!!!',
#   'Comment_author': {'channelId': 'UCPyrIv-3woyRXZozX_8UjAQ',
#    'videoId': 'YH1OxkAIFns',
#    'textDisplay': 'D SOUND QUALITY IS FUKD UP BUT STILL U LL LUV IT!!!!!',
#    'textOriginal': 'D SOUND QUALITY IS FUKD UP BUT STILL U LL LUV IT!!!!!',
#    'authorDisplayName': '@4degreesoffreedom',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kpOidYzHhv0_Yi1G4UZ8-Oe69y5Q1KY3ILc0_qC5Ttkk8=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@4degreesoffreedom',
#    'authorChannelId': {'value': 'UCPyrIv-3woyRXZozX_8UjAQ'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2012-02-06T06:23:44Z',
#    'updatedAt': '1970-01-01T00:00:00Z'},
#   'Comment_published': '2012-02-06T06:23:44Z'}]

# %%
#get playlist details
def get_playlist_info(channel_ids):
        next_page_token = None
        All_data = []
        while True:
                request = youtube.playlists().list(
                        part = "snippet,contentDetails",
                        channelId = channel_ids,
                        maxResults = 50,
                        pageToken = next_page_token
                    )

                response = request.execute()

                for item in response['items']:
                        data = dict(Playlist_Id = item['id'],
                                    Title = item['snippet']['title'],
                                    Channel_Id = item['snippet']['channelId'],
                                    Channel_Name = item['snippet']['channelTitle'],
                                    PublishedAt = item['snippet']['publishedAt'],
                                    Video_Count = item['contentDetails']['itemCount'])
                        All_data.append(data)

                next_page_token = response.get('nextPageToken')

                if next_page_token is None:
                    break
        return All_data

# %%
playlist_details = get_playlist_info("UCoC4TYHD1zDUYGmY59_5LCQ")

# %%
playlist_details
# Out:
# [{'Playlist_Id': 'PL7KrmHsMbH61lWxyMdg1XIfUvEbamFZ20',
#   'Title': 'Blacksheep Nagpuri playlist',
#   'Channel_Id': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#   'Channel_Name': 'BlackSheep Productions, Ranchi',
#   'PublishedAt': '2023-09-13T05:20:42.778353Z',
#   'Video_Count': 14},
#  {'Playlist_Id': 'PL7KrmHsMbH62rYyynYsnP6EGdDjIWS7It',
#   'Title': 'BEHIND THE SCENES',
#   'Channel_Id': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#   'Channel_Name': 'BlackSheep Productions, Ranchi',
#   'PublishedAt': '2021-07-11T06:33:41.276819Z',
#   'Video_Count': 3}]

# %%
# creat a clinent instance for MongoDB connection 
conn_str = "mongodb+srv://virenemmanuel:roomno13@cluster0.e6ecnpv.mongodb.net/project1?retryWrites=true&w=majority"
client = pymongo.MongoClient(conn_str)

#create a database or use existing one
db = client["Youtube_data"]

# %%
#create function to upload to MongoDB
def channel_details(channel_id):
    ch_details = get_channel_info(channel_id)
    pl_details = get_playlist_info(channel_id)
    vi_ids = get_videos_ids(channel_id)
    vi_details = get_video_info(vi_ids)
    com_details =get_comment_info(vi_ids)

    coll1=db["channel_details"]
    coll1.insert_one({"channel_information":ch_details,"playlist_information":pl_details,
                      "video_information":vi_details,"comment_information":com_details})
    
    return "upload completed successfully"

# %%
#              'UCPyrIv-3woyRXZozX_8UjAQ',   # 4 degrees of freedom
#              'UCtGrdfezQuXjdBek3Zv8bdg',   # Vanilla Chords
#              'UCmnlTWVJysjWPFiZhQ5uudg',   # Marty Music
#              'UCW3VuTWsyPWvT8fbyGrVpAQ',   # Kumar Shyam
#              'UCRBHXgLP8DbAAHfOYN_J4nw',   # Wanderlust A                                                                                                                                                                                                                                                                                                                                                                                                                                                      Nuj
#              'UCwVEhEzsjLym_u1he4XWFkg',   # Finance With Sharan
#              'UCoC4TYHD1zDUYGmY59_5LCQ',   # BlackSheep Productions
#              'UCSXa6jwF7pvL-qVdS1OnytA',   # Specxy Panda Bakes
#              'UCMwu5UL4nfp7upkIdr0dtWg'    # Gustavo carmo

# %%
insert = channel_details("UCSXa6jwF7pvL-qVdS1OnytA")

# %%
# Table creation for channels,playlists,videos,comments
def channels_table():
    mydb = psycopg2.connect(host = "localhost",
                            user = "postgres",
                            password = "roomno13",
                            database = "youtube_data",
                            port = "5432")

    cursor = mydb.cursor()

    drop_query = "drop table if exists playlists"
    cursor.execute(drop_query)
    mydb.commit()

    try:
        create_query = '''create table if not exists channels( Channel_Name varchar(100),
                                                               Channel_Id varchar(80) primary key,
                                                               Subscribers_Count bigint,
                                                               Views bigint,                     
                                                               Total_videos int,
                                                               Channel_Discription text,
                                                               Playlist_Id varchar(80))'''
        
        cursor.execute(create_query)
        mydb.commit()

    except:
        st.write("Channels table already created")


    ch_list = []
    db = client["youtube_data"]
    coll1 = db["channel_details"]
    for ch_data in coll1.find({},{"_id":0,"channel_information": 1}):
        ch_list.append(ch_data["channel_information"])
    df = pd.DataFrame(ch_list)

    for index, row in df.iterrows():
        insert_query = '''INSERT into channels( Channel_Name,
                                                Channel_Id,
                                                Subscribers_Count,
                                                Views,
                                                Total_Videos,
                                                Channel_Discription,
                                                Playlist_Id)
                                                VALUES(%s,%s,%s,%s,%s,%s,%s)'''
        
        values = (row['Channel_Name'],
                  row['Channel_Id'],
                  row['Subscribers_Count'],
                  row['Views'],
                  row['Total_Videos'],
                  row['Channel_Description'],
                  row['Playlist_Id'])
        try:
            cursor.execute(insert_query,values)
            mydb.commit()
        except:
            st.write("Channels values are already inserted")
    
channels_table()

# %%
ch_list = []
db = client["youtube_data"]
coll1 = db["channel_details"]
for ch_data in coll1.find({},{"_id":0,"channel_information": 1}):
        ch_list.append(ch_data["channel_information"])

# %%
ch_list
# Out:
# []

# %%
def playlist_table():
    mydb = psycopg2.connect(host="localhost",
            user = "postgres",
            password = "roomno13",
            database = "youtube_data",
            port = "5432")    
    cursor = mydb.cursor()  



    drop_query = "drop table if exists playlists"
    cursor.execute(drop_query)
    mydb.commit()

    try:
        create_query = '''create table if not exists playlists( PlaylistId varchar(100) primary key,
                                                                Title varchar(80),
                                                                ChannelId varchar(100),
                                                                ChannelName varchar(100),
                                                                PublishedAt timestamp,
                                                                Video_Count int) '''
        cursor.execute(create_query)
        mydb.commit()

    except:
        st.write("playlists Table already created")

    db = client["yputube_data"]
    coll1 = db["channel_details"]
    pl_list = []
    for pl_data in coll1.find({},{"_id":0,"playlist_information":1}):
        for i in range(len(pl_data["playlist_information"])):
            pl_list.append(pl_data["plalist_information"][i])
    df = pd.DataFrame(pl_list)

    for index,row in df.iterrows():
        insert_query = '''INSERT into playlists(PlaylistId,
                                                Title,
                                                ChannelId,
                                                ChannelName,
                                                PublishedAt,
                                                Video_Count)
                                        VALUES(%s,%s,%s,%s,%s,%s)'''
        values = ( row['PlaylistId'],
                   row['Title'],
                   row['ChannelId'],
                   row['Channelname'],
                   row['PublishedAt'],
                   row['Video_Count'])
        
        # try:
        cursor.execute(insert_query,values)
        mydb.commit()
        # except:
        #     st.write("playlists values are already inserted")
        

playlist_table()

# %%
def videos_table():
    mydb = psycopg2.connect(host="localhost",
                            user="postgres",
                            password="roomno13",
                            database="youtube_data",
                            port="5432")
    cursor = mydb.cursor()

    drop_query = "DROP TABLE IF EXISTS videos"
    cursor.execute(drop_query)
    mydb.commit()

    create_query = '''CREATE TABLE IF NOT EXISTS videos(Channel_Name varchar(100),
                                                        Channel_Id varchar(100),
                                                        Video_Id varchar(30) primary key,
                                                        Title varchar(150),
                                                        Tags text,
                                                        Thumbnail varchar(200),
                                                        Description text,
                                                        Published_Date timestamp,
                                                        Duration interval,
                                                        Views bigint,
                                                        Comments text, 
                                                        likes bigint,
                                                        Favorite_Count int,
                                                        Definition varchar(10),
                                                        Caption_Status varchar(50) 
                                                        )'''
    
    cursor.execute(create_query)
    mydb.commit()

    vi_list = []
    db = client["Youtube_data"]
    coll1 = db["video_details"]
    for vi_data in coll1.find({}, {"_id": 0, "video_information": 1}):
        for i in range(len(vi_data["video_information"])):
            vi_list.append(vi_data["video_information"][i])
    df = pd.DataFrame(vi_list)

  
    for index,row in df.iterrows():                
        insert_query = '''INSERT INTO videos( Channel_Name,
                                              Channel_Id,
                                              Video_Id,
                                              Title,
                                              Tags,
                                              Thumbnail,
                                              Description,
                                              Published_Date,
                                              Duration,
                                              Views,
                                              Comments, 
                                              likes,
                                              Favorite_Count,
                                              Definition,
                                              Caption_Status)

                            VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
                            ON CONFLICT (Video_Id) DO NOTHING'''

        values = (row["Channel_Name"],
                  row["Channel_Id"],
                  row["Video_Id"],
                  row["Title"],
                  row["Tags"],
                  row["Thumbnail"],
                  row["Description"],
                  row["Published_Date"],
                  row["Duration"],
                  row["Views"],
                  row["Comments"],
                  row["likes"],
                  row["Favorite_Count"],
                  row["Definition"],
                  row["Caption_Status"],

                  )

 
        cursor.execute(insert_query, values)
        mydb.commit()
    

videos_table()

# %%
vi_list = []
db = client["Youtube_data"]
coll1 = db["channel_details"]
for vi_data in coll1.find({}, {"_id": 0, "video_information": 1}):
    for i in range(len(vi_data["video_information"])):
        vi_list.append(vi_data["video_information"][i])

# %%
vi_list
# Out:
# [{'Channel_Name': 'BlackSheep Productions, Ranchi',
#   'Channel_Id': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#   'Video_Id': '15Ln7hjHlnE',
#   'Title': 'black sheep - new skies | canon 6d 50mm f/1.8 test | 720p',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/15Ln7hjHlnE/default.jpg',
#   'Description': '',
#   'Published_Date': '2017-05-04T15:38:37Z',
#   'Duration': 'PT2M10S',
#   'Views': '4926',
#   'Comments': None,
#   'likes': '81',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Gustavo Carmo',
#   'Channel_Id': 'UCMwu5UL4nfp7upkIdr0dtWg',
#   'Video_Id': 'a3PAmoOCOrw',
#   'Title': 'Gustavo Carmo - Hundreds of Thousands (Tony MacAlpine)',
#   'Tags': ['Aquiles Priester',
#    'Nando Mello',
#    'Gustavo Carmo',
#    'Tony MacAlpine',
#    'Hundres of Thousands',
#    'Instrumental Rock',
#    'Instrumental Metal',
#    'Guitar Shred',
#    'Guitar Player'],
#   'Thumbnail': 'https://i.ytimg.com/vi/a3PAmoOCOrw/default.jpg',
#   'Description': 'Produced by Aquiles Priester\nCo-Produced by Marcello Pompeu and Heros Trench\n\nVideo Direction by Sammy J. Riddle\nVideo Editing by Gustavo Carmo and Sammy J. Riddle\n\nDrums Recorded at Mr. Som Studio in Sao Paulo/SP -- Brazil\nBass Recorded at Estudio Midia by Adriano Aguiar in Gravatai/RS - Brazil\nGuitars Recorded at AK-47 Studios in Seattle/WA -- USA\n\nMixed and Mastered by Heros Trench at Mr. Som Studio\n\nArtist: Tony MacAlpine\nSong: Hundreds of Thousands\nMusic: Tony MacAlpine\nAlbum: Maximum Security - 1987\n\nMusicians:\n-Aquiles Priester - Drums\n-Nando Mello - Bass\n-Gustavo Carmo - Guitars\n-Tony MacAlpine - Keyboards',
#   'Published_Date': '2012-12-14T19:34:28Z',
#   'Duration': 'PT3M41S',
#   'Views': '107776',
#   'Comments': None,
#   'likes': '697',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Vanilla Chords',
#   'Channel_Id': 'UCtGrdfezQuXjdBek3Zv8bdg',
#   'Video_Id': 'zW4vsRCFeRw',
#   'Title': "What's Up - 4 Non Blondes | Chords and Lyrics",
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/zW4vsRCFeRw/default.jpg',
#   'Description': '#WhatsUp #4NonBlondes #GuitarChords #Lyrics #ChordsandLyrics #Chords #playalong #easyguitar #easyguitarchords #easychords\n\nThis channel is dedicated to encourage all guitar players / musicians across all levels.\n\nEnjoy playing along and practicing  with your favorite songs!\n\nPlease subscribe, like, share and comment to show your support.',
#   'Published_Date': '2021-01-29T19:41:45Z',
#   'Duration': 'PT5M21S',
#   'Views': '12354',
#   'Comments': None,
#   'likes': '133',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Vanilla Chords',
#   'Channel_Id': 'UCtGrdfezQuXjdBek3Zv8bdg',
#   'Video_Id': 'zW4vsRCFeRw',
#   'Title': "What's Up - 4 Non Blondes | Chords and Lyrics",
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/zW4vsRCFeRw/default.jpg',
#   'Description': '#WhatsUp #4NonBlondes #GuitarChords #Lyrics #ChordsandLyrics #Chords #playalong #easyguitar #easyguitarchords #easychords\n\nThis channel is dedicated to encourage all guitar players / musicians across all levels.\n\nEnjoy playing along and practicing  with your favorite songs!\n\nPlease subscribe, like, share and comment to show your support.',
#   'Published_Date': '2021-01-29T19:41:45Z',
#   'Duration': 'PT5M21S',
#   'Views': '12354',
#   'Comments': None,
#   'likes': '133',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Wanderlust ANuj',
#   'Channel_Id': 'UCRBHXgLP8DbAAHfOYN_J4nw',
#   'Video_Id': 'RTfDC4Fae9Q',
#   'Title': 'My first Vlog, Parasnath hill by bike, Ramgarh to Parasnath Part-1, Travel Video, Motovlogging',
#   'Tags': ['MOTOVLOGGER',
#    'TRAVEL VIDEO',
#    'BIKE RIDER',
#    'WANDERLUST ANUJ',
#    'JHARKHAND MOTOVLOGGER',
#    'RANCHI RIDER',
#    'pulsar ns 200',
#    'jharkhandi riders',
#    'parasnath hill by bike',
#    'parasnath hill tour',
#    'parasnath hill drone view',
#    'parasnath hill jharkhand status giridih',
#    'parasnath hill trekking',
#    'My first Vlog',
#    'Ramgarh to Parasnath hill',
#    'parasnath hill jharkhand',
#    'parasnath tempel',
#    'parasnath',
#    'parasnath mandir',
#    'Highest Peak Point of Jharkhand',
#    'best place to visit in jharkhand'],
#   'Thumbnail': 'https://i.ytimg.com/vi/RTfDC4Fae9Q/default.jpg',
#   'Description': "#parasnath #parasnathhilljharkhand #parasnathtempel #parshnathmandir #wanderlustanuj\nMy first Vlog, Ramgarh to Parasnath hill on Pulsar NS 200, Travel Video, Motovlogging, Parasnath hill by bike\n\n\nAll my Riding Gears, Gadgets, Accessories & Equipment: Shop Here👇 \nhttps://www.amazon.in/shop/wanderlustanuj\n(Amazon Certified)\n\nSubscribe to Alok Bhai's YouTube Channel (Ranchi Rider)\nhttps://www.youtube.com/channel/UCsIZd20TQWHtFoaUo0_ih3A\n\nTrack:  Marin Hoxha & Britt Lari - By Your Side \nMusic Provided by Magic Records\nListen To The Original:  https://youtu.be/PKcCS1KtWas\u200b\nFree Download:  https://fanlink.to/emEY\u200b\nUsage Policy: http://www.magicmusicLLC.com\n\n PLEASE, LIKE, SHARE,  SUBSCRIBE THE CHANNEL FOR MORE EXCITING VIDEO AND PLEASE DO COMMENT FOR ANY SUGGESTION FOR WHAT TYPE OF VIDEO YOU WANT PLEASE LET ME KNOW, I WILL GIVE MY BEST....THANK YOU...... GOD BLESS YOU...\n\n\nMy main Channel: https://www.youtube.com/c/WanderlustANuj\nMy second Channel: https://www.youtube.com/channel/UCWDnyAs-DB3o-fJadH3-woA\n\nFOLLOW ME \n\nON FACEBOOK  https://www.facebook.com/WanderlustANuj/\n \nON INSTAGRAM https://www.instagram.com/wanderlust_anuj/\n\nMOTOVLOGGER TRAVEL VIDEO BIKE RIDER WANDERLUST ANUJ JHARKHAND MOTOVLOGGER, RANCHI RIDER Jharkhandi Rider, Pulsar NS200 \nparasnath hill by bike\nparasnath hill tour\nparasnath hill drone view\nparasnath hill jharkhand status giridih\nparasnath hill trekking\n4500 Feet Highest Peak Point of Jharkhand\nbeautiful jharkhand\nbest place to visit in jharkhand\nbest picnic spot in jharkhand \nparasnath mandir temple",
#   'Published_Date': '2021-02-04T10:43:38Z',
#   'Duration': 'PT12M2S',
#   'Views': '5006',
#   'Comments': None,
#   'likes': '217',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': '4degreesoffreedom',
#   'Channel_Id': 'UCPyrIv-3woyRXZozX_8UjAQ',
#   'Video_Id': 'cpbIsMTYlxM',
#   'Title': '4 DEGREES OF FREEDOM PHOTO SYNC.wmv',
#   'Tags': ['4', 'DEGREES', 'OF', 'FREEDOM', 'PHOTO', 'SYNC'],
#   'Thumbnail': 'https://i.ytimg.com/vi/cpbIsMTYlxM/default.jpg',
#   'Description': '4 degrees of freedom photo sync',
#   'Published_Date': '2012-02-05T07:25:55Z',
#   'Duration': 'PT2M47S',
#   'Views': '299',
#   'Comments': None,
#   'likes': '7',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': 'ZZTqDPVPDiw',
#   'Title': 'Watermelon Slush&Mojito | तरबूज स्लश और मोहिटो |',
#   'Tags': ['#slush#mojito#watermelon'],
#   'Thumbnail': 'https://i.ytimg.com/vi/ZZTqDPVPDiw/default.jpg',
#   'Description': 'Refreshing Watermelon Slushie and Mojito to sooth your souls this summer.',
#   'Published_Date': '2020-05-24T20:16:36Z',
#   'Duration': 'PT3M56S',
#   'Views': '88',
#   'Comments': None,
#   'likes': '12',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Vanilla Chords',
#   'Channel_Id': 'UCtGrdfezQuXjdBek3Zv8bdg',
#   'Video_Id': 'zW4vsRCFeRw',
#   'Title': "What's Up - 4 Non Blondes | Chords and Lyrics",
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/zW4vsRCFeRw/default.jpg',
#   'Description': '#WhatsUp #4NonBlondes #GuitarChords #Lyrics #ChordsandLyrics #Chords #playalong #easyguitar #easyguitarchords #easychords\n\nThis channel is dedicated to encourage all guitar players / musicians across all levels.\n\nEnjoy playing along and practicing  with your favorite songs!\n\nPlease subscribe, like, share and comment to show your support.',
#   'Published_Date': '2021-01-29T19:41:45Z',
#   'Duration': 'PT5M21S',
#   'Views': '12354',
#   'Comments': None,
#   'likes': '133',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Vanilla Chords',
#   'Channel_Id': 'UCtGrdfezQuXjdBek3Zv8bdg',
#   'Video_Id': 'zW4vsRCFeRw',
#   'Title': "What's Up - 4 Non Blondes | Chords and Lyrics",
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/zW4vsRCFeRw/default.jpg',
#   'Description': '#WhatsUp #4NonBlondes #GuitarChords #Lyrics #ChordsandLyrics #Chords #playalong #easyguitar #easyguitarchords #easychords\n\nThis channel is dedicated to encourage all guitar players / musicians across all levels.\n\nEnjoy playing along and practicing  with your favorite songs!\n\nPlease subscribe, like, share and comment to show your support.',
#   'Published_Date': '2021-01-29T19:41:45Z',
#   'Duration': 'PT5M21S',
#   'Views': '12381',
#   'Comments': None,
#   'likes': '133',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Vanilla Chords',
#   'Channel_Id': 'UCtGrdfezQuXjdBek3Zv8bdg',
#   'Video_Id': 'zW4vsRCFeRw',
#   'Title': "What's Up - 4 Non Blondes | Chords and Lyrics",
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/zW4vsRCFeRw/default.jpg',
#   'Description': '#WhatsUp #4NonBlondes #GuitarChords #Lyrics #ChordsandLyrics #Chords #playalong #easyguitar #easyguitarchords #easychords\n\nThis channel is dedicated to encourage all guitar players / musicians across all levels.\n\nEnjoy playing along and practicing  with your favorite songs!\n\nPlease subscribe, like, share and comment to show your support.',
#   'Published_Date': '2021-01-29T19:41:45Z',
#   'Duration': 'PT5M21S',
#   'Views': '12381',
#   'Comments': None,
#   'likes': '133',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Wanderlust ANuj',
#   'Channel_Id': 'UCRBHXgLP8DbAAHfOYN_J4nw',
#   'Video_Id': 'RTfDC4Fae9Q',
#   'Title': 'My first Vlog, Parasnath hill by bike, Ramgarh to Parasnath Part-1, Travel Video, Motovlogging',
#   'Tags': ['MOTOVLOGGER',
#    'TRAVEL VIDEO',
#    'BIKE RIDER',
#    'WANDERLUST ANUJ',
#    'JHARKHAND MOTOVLOGGER',
#    'RANCHI RIDER',
#    'pulsar ns 200',
#    'jharkhandi riders',
#    'parasnath hill by bike',
#    'parasnath hill tour',
#    'parasnath hill drone view',
#    'parasnath hill jharkhand status giridih',
#    'parasnath hill trekking',
#    'My first Vlog',
#    'Ramgarh to Parasnath hill',
#    'parasnath hill jharkhand',
#    'parasnath tempel',
#    'parasnath',
#    'parasnath mandir',
#    'Highest Peak Point of Jharkhand',
#    'best place to visit in jharkhand'],
#   'Thumbnail': 'https://i.ytimg.com/vi/RTfDC4Fae9Q/default.jpg',
#   'Description': "#parasnath #parasnathhilljharkhand #parasnathtempel #parshnathmandir #wanderlustanuj\nMy first Vlog, Ramgarh to Parasnath hill on Pulsar NS 200, Travel Video, Motovlogging, Parasnath hill by bike\n\n\nAll my Riding Gears, Gadgets, Accessories & Equipment: Shop Here👇 \nhttps://www.amazon.in/shop/wanderlustanuj\n(Amazon Certified)\n\nSubscribe to Alok Bhai's YouTube Channel (Ranchi Rider)\nhttps://www.youtube.com/channel/UCsIZd20TQWHtFoaUo0_ih3A\n\nTrack:  Marin Hoxha & Britt Lari - By Your Side \nMusic Provided by Magic Records\nListen To The Original:  https://youtu.be/PKcCS1KtWas\u200b\nFree Download:  https://fanlink.to/emEY\u200b\nUsage Policy: http://www.magicmusicLLC.com\n\n PLEASE, LIKE, SHARE,  SUBSCRIBE THE CHANNEL FOR MORE EXCITING VIDEO AND PLEASE DO COMMENT FOR ANY SUGGESTION FOR WHAT TYPE OF VIDEO YOU WANT PLEASE LET ME KNOW, I WILL GIVE MY BEST....THANK YOU...... GOD BLESS YOU...\n\n\nMy main Channel: https://www.youtube.com/c/WanderlustANuj\nMy second Channel: https://www.youtube.com/channel/UCWDnyAs-DB3o-fJadH3-woA\n\nFOLLOW ME \n\nON FACEBOOK  https://www.facebook.com/WanderlustANuj/\n \nON INSTAGRAM https://www.instagram.com/wanderlust_anuj/\n\nMOTOVLOGGER TRAVEL VIDEO BIKE RIDER WANDERLUST ANUJ JHARKHAND MOTOVLOGGER, RANCHI RIDER Jharkhandi Rider, Pulsar NS200 \nparasnath hill by bike\nparasnath hill tour\nparasnath hill drone view\nparasnath hill jharkhand status giridih\nparasnath hill trekking\n4500 Feet Highest Peak Point of Jharkhand\nbeautiful jharkhand\nbest place to visit in jharkhand\nbest picnic spot in jharkhand \nparasnath mandir temple",
#   'Published_Date': '2021-02-04T10:43:38Z',
#   'Duration': 'PT12M2S',
#   'Views': '5006',
#   'Comments': None,
#   'likes': '217',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Finance With Sharan',
#   'Channel_Id': 'UCwVEhEzsjLym_u1he4XWFkg',
#   'Video_Id': 'FaZO7SyFg9I',
#   'Title': 'Before You Start Investing in Debt Mutual Funds Watch This..',
#   'Tags': ['debt funds',
#    'personal finance',
#    'mutual funds',
#    'debt mutual funds',
#    'bonds',
#    'savings account',
#    'fixed deposit'],
#   'Thumbnail': 'https://i.ytimg.com/vi/FaZO7SyFg9I/default.jpg',
#   'Description': "In this video I talk about about everything you need to know about debt mutual funds before you start investing in it. If you're someone who is just getting started with investing and is unaware of investment options apart from savings account and fixed deposits (FD) then this video will help you better understand the detailed working, risks and nuances of debt mutual funds and why having them in your portfolio would make financial sense in the long term. \n\n--------Contents of this video---------------------------\n0:00 - Intro\n0:54 - What is a debt mutual fund?\n1:29 - What is a bond?\n2:14 - Problems that debt fund solves?\n2:48 - Differences between fixed deposit and debt funds\n4:26 - Who should invest?\n5:45 - What are the risks?\n9:29 - Why you should invest?\n\nRelated video: \nHow much money to invest in debt funds and how to think about asset allocation? : https://www.youtube.com/watch?v=vPVdVTUllc4&t=2s\n\nWho am I:\nI'm Sharan Hegde, a management consultant turned fin-tech product manager working in Bangalore, India. I make videos about personal finance, technology and economy.\n\nGet in Touch:\nIf you'd like to talk you can reach out to me on LinkedIn: https://www.linkedin.com/in/sharan-he...",
#   'Published_Date': '2021-01-17T11:22:34Z',
#   'Duration': 'PT11M15S',
#   'Views': '52139',
#   'Comments': None,
#   'likes': '2214',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Finance With Sharan',
#   'Channel_Id': 'UCwVEhEzsjLym_u1he4XWFkg',
#   'Video_Id': 'FaZO7SyFg9I',
#   'Title': 'Before You Start Investing in Debt Mutual Funds Watch This..',
#   'Tags': ['debt funds',
#    'personal finance',
#    'mutual funds',
#    'debt mutual funds',
#    'bonds',
#    'savings account',
#    'fixed deposit'],
#   'Thumbnail': 'https://i.ytimg.com/vi/FaZO7SyFg9I/default.jpg',
#   'Description': "In this video I talk about about everything you need to know about debt mutual funds before you start investing in it. If you're someone who is just getting started with investing and is unaware of investment options apart from savings account and fixed deposits (FD) then this video will help you better understand the detailed working, risks and nuances of debt mutual funds and why having them in your portfolio would make financial sense in the long term. \n\n--------Contents of this video---------------------------\n0:00 - Intro\n0:54 - What is a debt mutual fund?\n1:29 - What is a bond?\n2:14 - Problems that debt fund solves?\n2:48 - Differences between fixed deposit and debt funds\n4:26 - Who should invest?\n5:45 - What are the risks?\n9:29 - Why you should invest?\n\nRelated video: \nHow much money to invest in debt funds and how to think about asset allocation? : https://www.youtube.com/watch?v=vPVdVTUllc4&t=2s\n\nWho am I:\nI'm Sharan Hegde, a management consultant turned fin-tech product manager working in Bangalore, India. I make videos about personal finance, technology and economy.\n\nGet in Touch:\nIf you'd like to talk you can reach out to me on LinkedIn: https://www.linkedin.com/in/sharan-he...",
#   'Published_Date': '2021-01-17T11:22:34Z',
#   'Duration': 'PT11M15S',
#   'Views': '52146',
#   'Comments': None,
#   'likes': '2215',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Vanilla Chords',
#   'Channel_Id': 'UCtGrdfezQuXjdBek3Zv8bdg',
#   'Video_Id': 'zW4vsRCFeRw',
#   'Title': "What's Up - 4 Non Blondes | Chords and Lyrics",
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/zW4vsRCFeRw/default.jpg',
#   'Description': '#WhatsUp #4NonBlondes #GuitarChords #Lyrics #ChordsandLyrics #Chords #playalong #easyguitar #easyguitarchords #easychords\n\nThis channel is dedicated to encourage all guitar players / musicians across all levels.\n\nEnjoy playing along and practicing  with your favorite songs!\n\nPlease subscribe, like, share and comment to show your support.',
#   'Published_Date': '2021-01-29T19:41:45Z',
#   'Duration': 'PT5M21S',
#   'Views': '14294',
#   'Comments': None,
#   'likes': '152',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Lamb of God',
#   'Channel_Id': 'UC4_yA-FDGB3Zwmk96E7yujA',
#   'Video_Id': 'aUdyrK1iw6E',
#   'Title': 'Contractor - New Lamb of God Teaser Track',
#   'Tags': ['lamb', 'of', 'god', 'official', 'contractor', 'wrath'],
#   'Thumbnail': 'https://i.ytimg.com/vi/aUdyrK1iw6E/default.jpg',
#   'Description': 'From the upcoming album Wrath, out Feb 24th!!',
#   'Published_Date': '2008-12-22T17:57:24Z',
#   'Duration': 'PT3M25S',
#   'Views': '358952',
#   'Comments': None,
#   'likes': '2387',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Vanilla Chords',
#   'Channel_Id': 'UCtGrdfezQuXjdBek3Zv8bdg',
#   'Video_Id': 'zW4vsRCFeRw',
#   'Title': "What's Up - 4 Non Blondes | Chords and Lyrics",
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/zW4vsRCFeRw/default.jpg',
#   'Description': '#WhatsUp #4NonBlondes #GuitarChords #Lyrics #ChordsandLyrics #Chords #playalong #easyguitar #easyguitarchords #easychords\n\nThis channel is dedicated to encourage all guitar players / musicians across all levels.\n\nEnjoy playing along and practicing  with your favorite songs!\n\nPlease subscribe, like, share and comment to show your support.',
#   'Published_Date': '2021-01-29T19:41:45Z',
#   'Duration': 'PT5M21S',
#   'Views': '16464',
#   'Comments': None,
#   'likes': '163',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Gustavo Carmo',
#   'Channel_Id': 'UCMwu5UL4nfp7upkIdr0dtWg',
#   'Video_Id': 'a3PAmoOCOrw',
#   'Title': 'Gustavo Carmo - Hundreds of Thousands (Tony MacAlpine)',
#   'Tags': ['Aquiles Priester',
#    'Nando Mello',
#    'Gustavo Carmo',
#    'Tony MacAlpine',
#    'Hundres of Thousands',
#    'Instrumental Rock',
#    'Instrumental Metal',
#    'Guitar Shred',
#    'Guitar Player'],
#   'Thumbnail': 'https://i.ytimg.com/vi/a3PAmoOCOrw/default.jpg',
#   'Description': 'Produced by Aquiles Priester\nCo-Produced by Marcello Pompeu and Heros Trench\n\nVideo Direction by Sammy J. Riddle\nVideo Editing by Gustavo Carmo and Sammy J. Riddle\n\nDrums Recorded at Mr. Som Studio in Sao Paulo/SP -- Brazil\nBass Recorded at Estudio Midia by Adriano Aguiar in Gravatai/RS - Brazil\nGuitars Recorded at AK-47 Studios in Seattle/WA -- USA\n\nMixed and Mastered by Heros Trench at Mr. Som Studio\n\nArtist: Tony MacAlpine\nSong: Hundreds of Thousands\nMusic: Tony MacAlpine\nAlbum: Maximum Security - 1987\n\nMusicians:\n-Aquiles Priester - Drums\n-Nando Mello - Bass\n-Gustavo Carmo - Guitars\n-Tony MacAlpine - Keyboards',
#   'Published_Date': '2012-12-14T19:34:28Z',
#   'Duration': 'PT3M41S',
#   'Views': '108013',
#   'Comments': None,
#   'likes': '701',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Gustavo Carmo',
#   'Channel_Id': 'UCMwu5UL4nfp7upkIdr0dtWg',
#   'Video_Id': 'a3PAmoOCOrw',
#   'Title': 'Gustavo Carmo - Hundreds of Thousands (Tony MacAlpine)',
#   'Tags': ['Aquiles Priester',
#    'Nando Mello',
#    'Gustavo Carmo',
#    'Tony MacAlpine',
#    'Hundres of Thousands',
#    'Instrumental Rock',
#    'Instrumental Metal',
#    'Guitar Shred',
#    'Guitar Player'],
#   'Thumbnail': 'https://i.ytimg.com/vi/a3PAmoOCOrw/default.jpg',
#   'Description': 'Produced by Aquiles Priester\nCo-Produced by Marcello Pompeu and Heros Trench\n\nVideo Direction by Sammy J. Riddle\nVideo Editing by Gustavo Carmo and Sammy J. Riddle\n\nDrums Recorded at Mr. Som Studio in Sao Paulo/SP -- Brazil\nBass Recorded at Estudio Midia by Adriano Aguiar in Gravatai/RS - Brazil\nGuitars Recorded at AK-47 Studios in Seattle/WA -- USA\n\nMixed and Mastered by Heros Trench at Mr. Som Studio\n\nArtist: Tony MacAlpine\nSong: Hundreds of Thousands\nMusic: Tony MacAlpine\nAlbum: Maximum Security - 1987\n\nMusicians:\n-Aquiles Priester - Drums\n-Nando Mello - Bass\n-Gustavo Carmo - Guitars\n-Tony MacAlpine - Keyboards',
#   'Published_Date': '2012-12-14T19:34:28Z',
#   'Duration': 'PT3M41S',
#   'Views': '108050',
#   'Comments': None,
#   'likes': '701',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'BlackSheep Productions, Ranchi',
#   'Channel_Id': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#   'Video_Id': '15Ln7hjHlnE',
#   'Title': 'black sheep - new skies | canon 6d 50mm f/1.8 test | 720p',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/15Ln7hjHlnE/default.jpg',
#   'Description': '',
#   'Published_Date': '2017-05-04T15:38:37Z',
#   'Duration': 'PT2M10S',
#   'Views': '4944',
#   'Comments': None,
#   'likes': '81',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'BlackSheep Productions, Ranchi',
#   'Channel_Id': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#   'Video_Id': '15Ln7hjHlnE',
#   'Title': 'black sheep - new skies | canon 6d 50mm f/1.8 test | 720p',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/15Ln7hjHlnE/default.jpg',
#   'Description': '',
#   'Published_Date': '2017-05-04T15:38:37Z',
#   'Duration': 'PT2M10S',
#   'Views': '4944',
#   'Comments': None,
#   'likes': '81',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'BlackSheep Productions, Ranchi',
#   'Channel_Id': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#   'Video_Id': '15Ln7hjHlnE',
#   'Title': 'black sheep - new skies | canon 6d 50mm f/1.8 test | 720p',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/15Ln7hjHlnE/default.jpg',
#   'Description': '',
#   'Published_Date': '2017-05-04T15:38:37Z',
#   'Duration': 'PT2M10S',
#   'Views': '4944',
#   'Comments': None,
#   'likes': '81',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Gustavo Carmo',
#   'Channel_Id': 'UCMwu5UL4nfp7upkIdr0dtWg',
#   'Video_Id': 'a3PAmoOCOrw',
#   'Title': 'Gustavo Carmo - Hundreds of Thousands (Tony MacAlpine)',
#   'Tags': ['Aquiles Priester',
#    'Nando Mello',
#    'Gustavo Carmo',
#    'Tony MacAlpine',
#    'Hundres of Thousands',
#    'Instrumental Rock',
#    'Instrumental Metal',
#    'Guitar Shred',
#    'Guitar Player'],
#   'Thumbnail': 'https://i.ytimg.com/vi/a3PAmoOCOrw/default.jpg',
#   'Description': 'Produced by Aquiles Priester\nCo-Produced by Marcello Pompeu and Heros Trench\n\nVideo Direction by Sammy J. Riddle\nVideo Editing by Gustavo Carmo and Sammy J. Riddle\n\nDrums Recorded at Mr. Som Studio in Sao Paulo/SP -- Brazil\nBass Recorded at Estudio Midia by Adriano Aguiar in Gravatai/RS - Brazil\nGuitars Recorded at AK-47 Studios in Seattle/WA -- USA\n\nMixed and Mastered by Heros Trench at Mr. Som Studio\n\nArtist: Tony MacAlpine\nSong: Hundreds of Thousands\nMusic: Tony MacAlpine\nAlbum: Maximum Security - 1987\n\nMusicians:\n-Aquiles Priester - Drums\n-Nando Mello - Bass\n-Gustavo Carmo - Guitars\n-Tony MacAlpine - Keyboards',
#   'Published_Date': '2012-12-14T19:34:28Z',
#   'Duration': 'PT3M41S',
#   'Views': '108060',
#   'Comments': None,
#   'likes': '701',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': '4degreesoffreedom',
#   'Channel_Id': 'UCPyrIv-3woyRXZozX_8UjAQ',
#   'Video_Id': 'cpbIsMTYlxM',
#   'Title': '4 DEGREES OF FREEDOM PHOTO SYNC.wmv',
#   'Tags': ['4', 'DEGREES', 'OF', 'FREEDOM', 'PHOTO', 'SYNC'],
#   'Thumbnail': 'https://i.ytimg.com/vi/cpbIsMTYlxM/default.jpg',
#   'Description': '4 degrees of freedom photo sync',
#   'Published_Date': '2012-02-05T07:25:55Z',
#   'Duration': 'PT2M47S',
#   'Views': '311',
#   'Comments': None,
#   'likes': '7',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': '4degreesoffreedom',
#   'Channel_Id': 'UCPyrIv-3woyRXZozX_8UjAQ',
#   'Video_Id': 'cpbIsMTYlxM',
#   'Title': '4 DEGREES OF FREEDOM PHOTO SYNC.wmv',
#   'Tags': ['4', 'DEGREES', 'OF', 'FREEDOM', 'PHOTO', 'SYNC'],
#   'Thumbnail': 'https://i.ytimg.com/vi/cpbIsMTYlxM/default.jpg',
#   'Description': '4 degrees of freedom photo sync',
#   'Published_Date': '2012-02-05T07:25:55Z',
#   'Duration': 'PT2M47S',
#   'Views': '311',
#   'Comments': None,
#   'likes': '7',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': 'ZZTqDPVPDiw',
#   'Title': 'Watermelon Slush&Mojito | तरबूज स्लश और मोहिटो |',
#   'Tags': ['#slush#mojito#watermelon'],
#   'Thumbnail': 'https://i.ytimg.com/vi/ZZTqDPVPDiw/default.jpg',
#   'Description': 'Refreshing Watermelon Slushie and Mojito to sooth your souls this summer.',
#   'Published_Date': '2020-05-24T20:16:36Z',
#   'Duration': 'PT3M56S',
#   'Views': '88',
#   'Comments': None,
#   'likes': '12',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': 'ZZTqDPVPDiw',
#   'Title': 'Watermelon Slush&Mojito | तरबूज स्लश और मोहिटो |',
#   'Tags': ['#slush#mojito#watermelon'],
#   'Thumbnail': 'https://i.ytimg.com/vi/ZZTqDPVPDiw/default.jpg',
#   'Description': 'Refreshing Watermelon Slushie and Mojito to sooth your souls this summer.',
#   'Published_Date': '2020-05-24T20:16:36Z',
#   'Duration': 'PT3M56S',
#   'Views': '88',
#   'Comments': None,
#   'likes': '12',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'BlackSheep Productions, Ranchi',
#   'Channel_Id': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#   'Video_Id': '15Ln7hjHlnE',
#   'Title': 'black sheep - new skies | canon 6d 50mm f/1.8 test | 720p',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/15Ln7hjHlnE/default.jpg',
#   'Description': '',
#   'Published_Date': '2017-05-04T15:38:37Z',
#   'Duration': 'PT2M10S',
#   'Views': '4972',
#   'Comments': None,
#   'likes': '82',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'BlackSheep Productions, Ranchi',
#   'Channel_Id': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#   'Video_Id': '15Ln7hjHlnE',
#   'Title': 'black sheep - new skies | canon 6d 50mm f/1.8 test | 720p',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/15Ln7hjHlnE/default.jpg',
#   'Description': '',
#   'Published_Date': '2017-05-04T15:38:37Z',
#   'Duration': 'PT2M10S',
#   'Views': '4972',
#   'Comments': None,
#   'likes': '82',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': 'ZZTqDPVPDiw',
#   'Title': 'Watermelon Slush&Mojito | तरबूज स्लश और मोहिटो |',
#   'Tags': ['#slush#mojito#watermelon'],
#   'Thumbnail': 'https://i.ytimg.com/vi/ZZTqDPVPDiw/default.jpg',
#   'Description': 'Refreshing Watermelon Slushie and Mojito to sooth your souls this summer.',
#   'Published_Date': '2020-05-24T20:16:36Z',
#   'Duration': 'PT3M56S',
#   'Views': '88',
#   'Comments': None,
#   'likes': '12',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': '2j5Do1E4iis',
#   'Title': 'Die with a smile #smile #moments #memories #brunomars #diewithsmile',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/2j5Do1E4iis/default.jpg',
#   'Description': '',
#   'Published_Date': '2025-01-13T13:05:23Z',
#   'Duration': 'PT23S',
#   'Views': '31',
#   'Comments': None,
#   'likes': '3',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': '2pTKT8DbT_8',
#   'Title': 'NSYNC BYE BYE BYE featuring crazy me😅🤣#deadpoolandwolverine #nsync #byebyebye #adieu2024',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/2pTKT8DbT_8/default.jpg',
#   'Description': '',
#   'Published_Date': '2025-01-07T14:08:04Z',
#   'Duration': 'PT38S',
#   'Views': '47',
#   'Comments': None,
#   'likes': '4',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': 'VFPrILVW_fw',
#   'Title': 'Christmas2024 prep #christmasbaking #christmas #christmascake',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/VFPrILVW_fw/default.jpg',
#   'Description': '',
#   'Published_Date': '2024-12-15T09:33:01Z',
#   'Duration': 'PT1M1S',
#   'Views': '16',
#   'Comments': None,
#   'likes': '0',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': 'r3F7kEVOXKo',
#   'Title': 'Singalong🎧 #borracaves #vizag #singalong',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/r3F7kEVOXKo/default.jpg',
#   'Description': '',
#   'Published_Date': '2024-12-14T02:12:25Z',
#   'Duration': 'PT34S',
#   'Views': '13',
#   'Comments': None,
#   'likes': '1',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': 'GeI2icbD-H4',
#   'Title': "Ho!ho!ho! It's christmas again🎄🎁Seasons greetings🎉🎄#christmas #christmasbaking #christmascake #hope",
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/GeI2icbD-H4/default.jpg',
#   'Description': '',
#   'Published_Date': '2024-12-05T17:52:52Z',
#   'Duration': 'PT32S',
#   'Views': '8',
#   'Comments': None,
#   'likes': '1',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': 'WH3HVKdtqfM',
#   'Title': 'Meet drama queen of my fam💕#nautanki #expression #funnyshorts #cute #bachpan #bachhe #masti #drama',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/WH3HVKdtqfM/default.jpg',
#   'Description': '',
#   'Published_Date': '2024-11-30T11:07:30Z',
#   'Duration': 'PT11S',
#   'Views': '24',
#   'Comments': None,
#   'likes': '4',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': 'qSL0mEMk06c',
#   'Title': 'भतीजे ने बनाया झटपट चिकन कबाब।PAN fried chicken kebab made in very little oil.Full of flavors.',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/qSL0mEMk06c/default.jpg',
#   'Description': 'Chicken kebab in frying pan using very little oil.\nFeaturing my baby nephew chef Arpit.\nDo support by liking and sharing the video to encourage the young chef.🙏🤗😎',
#   'Published_Date': '2024-09-01T18:19:17Z',
#   'Duration': 'PT1M',
#   'Views': '387',
#   'Comments': None,
#   'likes': '8',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': 'N0iJeUQjHsQ',
#   'Title': 'Dogday and catnap clay charms.Model:DJ baby',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/N0iJeUQjHsQ/default.jpg',
#   'Description': 'Dogday and catnap charms sun and moon made with kids superclay.Also rainbow is made and turned into locket.Modelling done by DJ baby adorning the charms.',
#   'Published_Date': '2024-07-14T06:14:57Z',
#   'Duration': 'PT29S',
#   'Views': '11',
#   'Comments': None,
#   'likes': '0',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': 'OaInSlvwTug',
#   'Title': 'when a baker starts making earrings😂🍩',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/OaInSlvwTug/default.jpg',
#   'Description': '',
#   'Published_Date': '2024-06-30T16:22:21Z',
#   'Duration': 'PT27S',
#   'Views': '40',
#   'Comments': None,
#   'likes': '6',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': 'RQsogQQxQMg',
#   'Title': 'Happiness blooms in my garden🌿',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/RQsogQQxQMg/default.jpg',
#   'Description': '',
#   'Published_Date': '2024-06-29T12:23:20Z',
#   'Duration': 'PT1M1S',
#   'Views': '430',
#   'Comments': None,
#   'likes': '11',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': 'DErq97DpFT8',
#   'Title': 'Instant Mawa Recipe from Milk Powder |अब घंटो मावा बनाने का झंझट खत्म। मिनटों में बनाए इंस्टैंट मावा',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/DErq97DpFT8/default.jpg',
#   'Description': 'Instant Mawa made from Milk powder in just 5 minutes.\nuseful to make any type of sweets at comfort of house such as peda,barfi,Mawa cakes etc.\nGive this simple recipe a try and enjoy making sweets in no time.\n\ningredients\nGhee-2tbsp\nmilk powder-2 cup\nmilk-1 cup\n\n\n\nAlso visit👇\nTiranga mithai from instant mawa\nhttps://youtu.be/R9NMIaQgb4M',
#   'Published_Date': '2021-11-30T05:26:18Z',
#   'Duration': 'PT3M58S',
#   'Views': '108',
#   'Comments': None,
#   'likes': '7',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': 'ntYX37eJgMU',
#   'Title': 'Dragon chicken।।घर पर बनाएं रेस्टोरेंट जैसा ड्रैगन चिकन।',
#   'Tags': ['#chicken #chickenrecipes #dragonchicken #indochinese #fastfood #starter #snacks'],
#   'Thumbnail': 'https://i.ytimg.com/vi/ntYX37eJgMU/default.jpg',
#   'Description': 'Dragon chicken is an indo chinese cuisine mostly loved in form of starter or side dish.\nEasy recipe thar yields restaurant like results.\nGive it a try n enjoy.😎\n\nIngredients :\n\nBoneless chicken-250 gms\nSeasoning:\nSalt-to taste\nBlack pepper powder-1/2tbsp\n\nFor batter:\nApf/maida-3tbsp\nCorn flour-2tbsp\nSalt-a pinch\nBlack pepper powder - 1/4 tbsp\nBaking powder-1/4 tbsp\nWater-adjust to make smooth flowy batter\nEgg-1\n\nOil-for frying+2tbsp\nGarlic-7-8 chopped\nRed chilly-4-5\nOnion-1chopped\nGreen/red chilly sauce-2tbsp\nTomato ketchup - 2tbsp\nCapsicum (medium size) - 1/2 julienne\nCashewnuts-7-8 fried\nWater-1/4 cup\nSalt-to taste\nSugar-1/2tbsp\nRed Chilly powder-1/2tbsp\n\n\n\n\n\n\nHoney Barbeque chicken👇\nhttps://youtu.be/a9wGD9fdT18\n\nLime Honey Chicken👇\nhttps://youtu.be/LCrvSI00GI4\n\nCrumb fried chicken👇\nhttps://youtu.be/nlanrGCrNeg',
#   'Published_Date': '2021-08-29T14:49:11Z',
#   'Duration': 'PT7M14S',
#   'Views': '182',
#   'Comments': None,
#   'likes': '12',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': '2dSeaNPjF6I',
#   'Title': 'Black forest pastry ।।ब्रैड से बनाएं ब्लैक फॉरेस्ट पेस्ट्री घर पर आसान तरीक़े से।',
#   'Tags': ['#blackforest #pastry #blackforestpastry #bread #nobake'],
#   'Thumbnail': 'https://i.ytimg.com/vi/2dSeaNPjF6I/default.jpg',
#   'Description': 'Black forest Pastry made from bread.\nIts a very simple n easy recipe and tastes no less than an authentic black forest Pastry.\nGive it a try and enjoy.\nNo bake recipe only involves assembling.\n\nIngredients: \nBread -4 slices (4 layers)\nCherries-4-5 chopped,2 whole- for garnish\nSugar-1 tbsp\nWater-1/4 cup\nWhipped cream-for frosting\nDark chocolate-grated ( for sprinkling on pastry)\n\nMethod:\nFirst in a pan take water,sugar,chopped cherries.Put to boil.Cherry syrup is ready.\n\nTake bread slice.Trim edges.Take on slice,soak with cherry syrup,place cherries,frost with whipping cream,place 2nd bread slice over then repeat same steps.\nSoaking,cherries,frosting then next bread slice.\nMake 4 layers in the same way.\nOn top layer frost with whipped cream.Smoothen.Frost all sides of bread and smoothen.\nFinally sprinkle grated chocolate all over.\nGarnish with some whipped cream and cherries on the top.\nYour no bake black forest Pastry is ready.\nEnjoy.\n\nSee kiwi cake recipe here👇\nhttps://youtu.be/HoY-uiXVLSQ\n\nMango glaze cake👇\nhttps://youtu.be/JCLn277Rk9U\n\nOreo Brownie 👇\nhttps://youtu.be/nK5mY7L3HQg',
#   'Published_Date': '2021-08-25T17:46:25Z',
#   'Duration': 'PT5M51S',
#   'Views': '160',
#   'Comments': None,
#   'likes': '12',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': 'R9NMIaQgb4M',
#   'Title': '15 अगस्त को बनाइए तिरंगा मिठाई ब्रैड से।Tri color sweet | Easy quick Recipe',
#   'Tags': ['#independenceday #festival #sweet #bread #coconutflakes'],
#   'Thumbnail': 'https://i.ytimg.com/vi/R9NMIaQgb4M/default.jpg',
#   'Description': 'Tri color sweet is prepared from bread,Mawa, Dessicated coconut and sugar syrup.Very easy n no flame recipe.\nSweet way to showcase your patriotism.\nEnjoy.\nJai hind Jai Bharat.😍\n\n*Pl ignore some tech errors.\n\n\nIngredients:\nBread-18-20 slice (depends on size of bread n size of mithai u r going to make)\nSugar-1cup\nWater-1 cup\nDessicated coconut- for coating\nMawa-for filling (approx 150-200 gms,Qty depends on how much u like Mawa)\nFood color- few drops of orange and green.\nAlmonds/cashew- to garnish\n\nMethod:\nCut bread slices in desired shape.\nMake sugar syrup by boiling 1 cup water+1 cup sugar.Dont make any string consistency,just dissolve sugar completely.\nDivide in 3 equal parts.\nAdd orange to one n green to one part.\nDip bread in sugar syrup,squeeze excess,fill Mawa,dip another bread in syrup,squeeze,then place over Mawa filled bread.\nPress a bit.Roll in Dessicated coconut n Garnish with almond/cashew.\nFor orange n green color Dessicated coconut, Add few drops of orange and green to it.\nAccordingly coat orange mithai in orange Dessicated coconut n green mithai in green Dessicated coconut.\nAnd your Tri color mithai is ready in no time.\n\nVisit tricolor semolina dhokla 👇\nhttps://youtu.be/atIe_PW_ybg',
#   'Published_Date': '2021-08-15T12:03:11Z',
#   'Duration': 'PT4M36S',
#   'Views': '89',
#   'Comments': None,
#   'likes': '6',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': 'umRnZt3cXL4',
#   'Title': 'Coconut Laddoo | आसानी से झटपट घर पर बनाएं टेस्टी नारियल लड्डू।',
#   'Tags': ['#coconut #laddoo # coconutladdoo #condensedmilkrecipe #milk #sweet #dessert'],
#   'Thumbnail': 'https://i.ytimg.com/vi/umRnZt3cXL4/default.jpg',
#   'Description': "Easy coconut Laddoos ready in no time.\nPrepared just in 10 min.For your sweet tooth when running short of time.\nLast min sweet preparation.Yet so delectable.Give it a try friends.Enjoy.\n\nIngredients:\nBasically only 2 major ingredients are used i.e Dessicated Coconut and condensed milk,hence this recipe is mostly a 2 ingredients Coconut Laddoos recipe.\n\n1)Dessicated coconut-1 cup\n(Fresh grated Coconut can also be taken.)\n2)Condensed milk (milkmade/mithaimate or you can use homemade condensed milk)-1/4 cup\n(Also some Powdered sugar can be added if you like it sweeter)\n3)Ghee-1 tbsp\n(And A little to grease if at all reqd in shaping Laddoos)\n4)Milk-1 tbsp (optional)\n\nHeat ghee in a wok,roast Dessicated Coconut till it changes its color slightly.\nAdd condensed milk and mix,Later on add 1 tbsp milk and mix again well.\nCheck the mixture,if holding shape it's done.\nTake out mixture in a bowl.\nLet it cool a bit,when mixture is still warm shape into Laddoos.Roll Laddoos in Dessicated Coconut for more beautiful n tastier look n feel.\nYour Coconut Laddoos are ready.Enjoy.\n\nCheck out some more dessert recipes🍰😋👇\n\n3 min Brownie recipe here👇\nhttps://youtu.be/nK5mY7L3HQg\n\nChoco cake pops👇\nhttps://youtu.be/51e5hbljNyM\n\n2 min microwave muffin recipe here👇\nhttps://youtu.be/zPTYI7i8fLM\n\nNo bake oreo fudge👇😋\nhttps://youtu.be/hi0jVtHgqIA\n\nFollow us on insta 👇\nhttps://instagram.com/specxypandabakes?utm_medium=copy_link\n\nJoin me on FB👇\nhttps://www.facebook.com/Specxy-Panda-Bakes-103394294768981/",
#   'Published_Date': '2021-08-08T04:41:51Z',
#   'Duration': 'PT2M56S',
#   'Views': '118',
#   'Comments': None,
#   'likes': '6',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': 'f8k2vqhRnxc',
#   'Title': 'Bread Pizza Coins | ब्रेड पिज़्ज़ा कॉइन। आसानी से मिनटों में बनाए ब्रैड का कुरकुरा स्नैक्स ।',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/f8k2vqhRnxc/default.jpg',
#   'Description': 'Bread Pizza Coins is a quick snack recipe especially loved by kids. A Crunchy snack loaded with veggies and oozing out with melting cheese.\nGive it a try and enjoy.\n\n\nIngredients:\nBread slice- 6 (you can take as much as you want to make,6 slices yields 3 bread pizza Coins)\nCheese-1-2 slice or cheese cube(Qty can be increased or decreased as per your choice)\nCapsicum-1 tbsp Finely chopped\nOnion-1 tbsp Finely chopped\nBeans-1 tbsp Finely chopped\nCarrots-1 tbsp Finely chopped\nTomato-1/2 tbsp Finely chopped\n☝️"You can take any veggies you like."\nOlives-1/2 tbsp Finely chopped\nOregano-1/4 tbsp\nBlack pepper powder-a pinch\nPizza sauce-1/2 tbsp\nMayonnaise-1 tbsp\nKetchup-1/2 tbsp\nChilly flakes-1/4 tbsp\nMixed herbs-a pinch (optional)\nMelted butter- 1 tbsp (to brush)\n\nCut bread slices in circles using cookie cutter or katori.\nCut rings out of 3 of them using smaller cookie cutter.\nPrepare filling usling veggies,black pepper powder,pizza sauce,olives,oregano,chilly flakes and cheese. \nPrepare mayo sauce by adding mayo n ketchup.\nNow take bread circle,Spread mayo sauce,paste ring onto it.\nAdd filling inside coin ring.\nAdd more cheese on top.sprinkle with some mixed herbs and brush butter.\nBake till cheese melts.\nYour bread pizza coin is ready.\nEnjoy this Crunchy beauty immediately.\n\nFollow us on insta 👇\nhttps://instagram.com/specxypandabakes?utm_medium=copy_link\n\nJoin me on FB👇\nhttps://www.facebook.com/Specxy-Panda-Bakes-103394294768981/',
#   'Published_Date': '2021-08-01T06:48:14Z',
#   'Duration': 'PT5M38S',
#   'Views': '106',
#   'Comments': None,
#   'likes': '7',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': 'LCrvSI00GI4',
#   'Title': 'Lime Honey Chicken। बोनलेस चिकन ब्रेस्ट की आसान रेसीपी बिना मैरीनेट किए।',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/LCrvSI00GI4/default.jpg',
#   'Description': 'An easy Honey glazed Chicken breast recipe with a tang of lime.\nBliss for continental lovers.No marinate recipe.Perfect for starter or even a full meal.\nGive it a try.Enjoy guys.🙏\n\n\n\n\nVisit Specxy Panda Bakes FB page👇\nhttps://www.facebook.com/Specxy-Panda-Bakes-103394294768981/',
#   'Published_Date': '2021-07-25T05:36:56Z',
#   'Duration': 'PT6M50S',
#   'Views': '168',
#   'Comments': None,
#   'likes': '14',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': 'wn9Xvy-11IE',
#   'Title': 'आसानी से झटपट बनाएं मैगी चीज़ पकोड़ा । Maggi Cheese Pakoda | मैगी चीज़ पकोड़े।',
#   'Tags': ['#maggi #noodles #fritters #cheese #pakoda'],
#   'Thumbnail': 'https://i.ytimg.com/vi/wn9Xvy-11IE/default.jpg',
#   'Description': 'जब मन करे कुछ चीज़ी, कुरकुरा खाने का, बनाएं मैगी चीज़ पकोड़े।\nअंदर से पिघलता हुआ चीज़ और बाहर मैगी का क्रंच।\n quick snack ready in minutes.\nVery less ingredients.\nCrunchy from outside and oozing with cheese from inside.\nYummy snack loved by one and all.\n\nIngredients:\n\nMaggi noodles- 1 block\nMaggi tastemaker- 1 pouch\nCheese cubes- 3\nAll purpose flour- 3 tbsp\nWater- as required\nSalt-a pinch\nRed chilly powder- a pinch\nMixed herbs-1 tbsp\nOil- to fry\n\nMethod:\n\nCrush maggi to crumbs.Take apf,salt,maggi tastemaker,red chilly powder and mix.Add water to make semi thick flowy batter.\nTake cheese cubes,cut in triangle,slit halfway n stuff mixed herbs.\nCoat cheese triangles in batter then roll in Maggi crumbs.\nPrepare all cheese in same way.\nFry in hot oil till golden brown.\nServe hot.\n\nhttps://www.facebook.com/Specxy-Panda-Bakes-103394294768981/',
#   'Published_Date': '2021-07-04T09:04:47Z',
#   'Duration': 'PT5M28S',
#   'Views': '114',
#   'Comments': None,
#   'likes': '14',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': 'a9wGD9fdT18',
#   'Title': 'Honey Barbeque Sauce Chicken | हनी बार्बेक्यू सॉस चिकन |',
#   'Tags': ['#Honey Chicken #barbeque sauce #chicken #chicken snacks #honey glazed Chicken #fried chicken'],
#   'Thumbnail': 'https://i.ytimg.com/vi/a9wGD9fdT18/default.jpg',
#   'Description': 'Honey glazed Chicken tossed in hot Barbeque Sauce.Delightful tangy n sweet snack.Crunchy juicy recipe.Crispy fried chicken tossed in Barbeque sauce with a dash of honey.Yum snack for chicken lovers.\n\nhttps://www.facebook.com/Specxy-Panda-Bakes-103394294768981/',
#   'Published_Date': '2020-12-06T15:59:21Z',
#   'Duration': 'PT4M33S',
#   'Views': '141',
#   'Comments': None,
#   'likes': '8',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': 'fBpPLQu-0FE',
#   'Title': 'Hot Chocolate | Easy & Quick Recipe | हॉट चॉकलेट | आसानी से झटपट तैयार|',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/fBpPLQu-0FE/default.jpg',
#   'Description': 'Hot chocolate never goes off the menu.Fav recipe for winter.Yummy  chocolate incorporated with goodness of milk.Topped with whipped cream.What a delightful drink.❤️\nGive this easy recipe a try.You n your kids will love it for sure.👍Enjoy piping hot.\n\nIngredients:\nDark chocolate or semi sweet/milk chocolate grated(as per choice)- 1 cup\nMilk-2 cups\nSugar-1-2 tbsp (as per liking)\n\nGarnish:(optional)\nWhipped cream-3-4 tbsp\nMarshmallow stick\n\nMethod:\nAdd 3 tbsp grated Chocolate and  sugar to milk and put to boil while stirring.Switch off the flame once milk is boiled.\nTop with some whipped cream, chocolate flakes and marshmallow stick.Serve hot.😋',
#   'Published_Date': '2020-11-22T11:50:24Z',
#   'Duration': 'PT3M3S',
#   'Views': '70',
#   'Comments': None,
#   'likes': '7',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': 'nK5mY7L3HQg',
#   'Title': 'Oreo Brownies | 3 min Microwave Recipe | ओरियो ब्राउनी | माइक्रोवेव रेसिपी |',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/nK5mY7L3HQg/default.jpg',
#   'Description': 'Soft n spongy Brownies made in minutes from Oreo Cookies.\nYummy delight.',
#   'Published_Date': '2020-11-15T12:25:35Z',
#   'Duration': 'PT4M50S',
#   'Views': '74',
#   'Comments': None,
#   'likes': '5',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': 'zPTYI7i8fLM',
#   'Title': '2 min Microwave Muffins | Eggless,No condensed Milk,No Butter |2  मिनट में \u200c\u200cमाइक्रोवेव कप केक |',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/zPTYI7i8fLM/default.jpg',
#   'Description': 'Muffins/Cup Cakes ready in microwave in just 2 mins.Easy hassle free quick recipe for fluffy muffins.Best for you last moment suagr cravings.A quick fix.❤️Yummy n tasty.',
# ...
#   'Published_Date': '2020-08-22T11:06:05Z',
#   'Duration': 'PT4M12S',
#   'Views': '156',
#   'Comments': None,
#   'likes': '15',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': 'atIe_PW_ybg',
#   'Title': 'Tricolor semolina dhokla | तिरंगा सूजी/रवा ढोकला|',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/atIe_PW_ybg/default.jpg',
#   'Description': 'Celebrate this independence day with tricolor semolina/sooji/rava dhokla.\nWhat would be better than expression of patriotism through ones art.\nTribute to our motherland with such an easy peesy yet tasty & beautiful recipe.\nHappy 74th Independence day dear all.❤️',
#   'Published_Date': '2020-08-15T09:59:44Z',
#   'Duration': 'PT4M31S',
#   'Views': '80',
#   'Comments': None,
#   'likes': '7',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': '_XiNmCFO-60',
#   'Title': 'World Indigenous Day special Cake | विश्व आदिवासी दिवस विशेष केक।',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/_XiNmCFO-60/default.jpg',
#   'Description': "Reflecting the zeal and enthusiasm of being a proud Tribal by cake art.\nSimple Decor anyone can try.\n\nMango Glaze cake recipe👇\nhttps://youtu.be/JCLn277Rk9U\n\nFor Plain vanilla cake: Don't add Mango Glaze while preparing batter.\nDon't top with mango Glaze after baked.Adjust/increase sugar amount as not adding Mango Glaze.\n\nBanana Custard cake👇\nhttps://youtu.be/fOE0rsNj1SI\n\nFor plain vanilla cake: Don't add banana to batter,rest steps are same.and don't spread Custard once baked.Adjust/increase sugar amount as not adding banana.\nRest of the steps are same.\n\nIf baking in microwave bake at 180°C for 35-40 mins in convection mode.",
#   'Published_Date': '2020-08-12T09:29:09Z',
#   'Duration': 'PT4M10S',
#   'Views': '111',
#   'Comments': None,
#   'likes': '12',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': 'REqKYcwhq94',
#   'Title': 'Edible Rakhi & Friendship Bands | Easy | राखी और फ्रेंडशिप बैंड्स, केक और मफिन्स से आसानी से बनाएं।',
#   'Tags': ['#rakhi#ediblerakhi#edibleFriendshipbands'],
#   'Thumbnail': 'https://i.ytimg.com/vi/REqKYcwhq94/default.jpg',
#   'Description': 'Edible rakhis made of cake and friendship band made of muffins.\nBring more joy to this Friendship and rakhi season by trying this interesting stuff.\nWarmth of rakhi with delicious edible cake rakhis is bliss.Surprise your friends with this yummy edible muffin friendship band.Simple recipe.Give it a try.Use any flavour of your choice.Enjoy.Spread love.❤️\n\nMango glazed cake👇\nhttps://youtu.be/JCLn277Rk9U\n\nBanana Custard cake👇\nhttps://youtu.be/fOE0rsNj1SI\n\nFor basic sponge cake\n1)vanilla- Follow above recipes,Skip adding Mango Glaze/banana to batter.\n2)Chocolate-Follow above recipes,reduce all purpose flour by 2 tbsp in quantity,Add 4 tbsp cocoa powder.',
#   'Published_Date': '2020-08-02T06:48:19Z',
#   'Duration': 'PT6M38S',
#   'Views': '105',
#   'Comments': None,
#   'likes': '6',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': 'zTxzOuKmof8',
#   'Title': 'Chicken Biryani | Simple Recipe | चिकन बिरयानी | आसान रेसिपी|',
#   'Tags': ['#Biryani#chickenbiryani#easychickenbiryani'],
#   'Thumbnail': 'https://i.ytimg.com/vi/zTxzOuKmof8/default.jpg',
#   'Description': 'Relish all time favorite Chicken biryani this Bakrid.\nEvergreen recipe.Basmati rice simmered with marinated chicken pieces along with whole spices.\nAromatic fulfilling one pot dish.\nEnjoy with raita and salad.',
#   'Published_Date': '2020-08-01T03:33:57Z',
#   'Duration': 'PT5M35S',
#   'Views': '131',
#   'Comments': None,
#   'likes': '12',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': 'JCLn277Rk9U',
#   'Title': 'Eggless Mango Glaze Cake || No oven || No curd || No Condensed Milk || एगलेस मैंगो केक ||',
#   'Tags': ['#mango cake#cake#noOvencake#eggless'],
#   'Thumbnail': 'https://i.ytimg.com/vi/JCLn277Rk9U/default.jpg',
#   'Description': "Eggless mango sponge cake prepared with fresh ripe mangoes and goodness of milk.Sparkling mango glaze is cherry on the top.No need of an oven.Try this simple and amazing recipe in pressure cooker and relish it's heavenly flavors.\n\nIngredients:\nFor Glaze:\nRipe Mango-1 medium size\nSugar-1 cup\nFor Decor:\nDark chocolate:100 gms\n\nAll purpose Flour- 1 cup\nMilk -1/2 cup\nBrown/Regular sugar(powdered)-1 cup\nRefined Oil-1/2 cup\nVanilla Essence-1 tbsp\nBaking Powder-1/2 tbsp\nBaking Soda-1/8 tbsp\nSalt- a pinch(optional) *i didn't use though😁\n\nRecipe:\nGrind Mango pulp.Cook with sugar till translucent.Glaze is ready.\nFor cake:\nPrepare pressure cooker with a stand inside to place cake tin over,or use a bowl/katori or put some salt,make a heap and then put cake tin over it.\nPreheat it for some time.\nBatter: In a mixing bowl add powdered brown sugar (regular sugar will also do),oil,milk and whisk till sugar dissolves.Add 1 tbsp vanilla essence.\nSift all purpose flour,baking powder,baking soda and mix.Add 3 tbsp Mango Glaze and Miz again.Batter is ready.\nPour batter in cake tin with parchment paper or grease n dust before pouring the batter in.\nTap Once/twice then put in cooker over stand/salt.\nCover the lid and remove whistle.\nCook for about 35-40 mins.\nCheck with toothpick.If it comes clean then cake is done.\nDemould it.Let it cool then decorate \nSpread some Mango Glaze on cake.Melt some dark chocolate,fill in piping bag and draw lines as shown in video \nUsing toothpick scrape n make designs(shown in video).\nYour Eggless mango Glaze cake is ready.\nEnjoy with your near and dear ones.❤️\n\nBanana Custard cake👇\nhttps://youtu.be/fOE0rsNj1SI\n\n1min Mug cake👇\nhttps://youtu.be/-Ld5tYaCzYg",
#   'Published_Date': '2020-07-26T04:26:29Z',
#   'Duration': 'PT5M46S',
#   'Views': '147',
#   'Comments': None,
#   'likes': '11',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': 'YQ69bHBYq6Y',
#   'Title': 'Baked Piri Piri Potato Chips |  आलू चिप्स । बेक  किए हुए । पेरी पेरी फ्लेवर में।',
#   'Tags': ['#bakedchips#healthysnack#noOilchips#microwave snack'],
#   'Thumbnail': 'https://i.ytimg.com/vi/YQ69bHBYq6Y/default.jpg',
#   'Description': 'Crunchy potato chips baked in a microwave oven,spiced up with Piri Piri mix.\nLip smacking munchies tasty and healthy at the same time.\nSo why worrying you health freaks out there.\nA perfect solution to satiate your snacks cravings on healthier side.\nGive it a try and enjoy.\nKeep baking.❤️\n\n\nIngredients: \n\nPotato - 4 Medium Size\nOlive oil - To brush\nSalt - To taste\nPiri Piri Mix - 1/2 Tbsp\nRed Chilly Powder - 1/4 Tbsp\nChaat Masala - 1/4 Tbsp',
#   'Published_Date': '2020-07-19T11:44:54Z',
#   'Duration': 'PT3M38S',
#   'Views': '121',
#   'Comments': None,
#   'likes': '11',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': 'lAAtuK__rPU',
#   'Title': 'Veg Zinger Parcel | Dominos Style| वेज ज़िंगर पार्सल। डोमिनोज़ स्टाईल में।',
#   'Tags': ['#zingy parcel#paneer parcel#dominos zingy parcel'],
#   'Thumbnail': 'https://i.ytimg.com/vi/lAAtuK__rPU/default.jpg',
#   'Description': 'Zinger Parcel stuffed with Paneer spiced with Harissa mayonnaise.Fluffy bread filled with soft tangy paneer,loaded with mozerilla cheese(optional) and hint of mixed herbs.\nA world famous snack from Dominos.\nMaiden attempt at home and was worth trying.\nEnjoy this lovely Zinger Parcel with your loved ones.❤️',
#   'Published_Date': '2020-07-12T12:36:37Z',
#   'Duration': 'PT6M22S',
#   'Views': '158',
#   'Comments': None,
#   'likes': '13',
#   'Favorite_Count': '0',
#   'Definition': 'sd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': 'V5j_koWHtlU',
#   'Title': 'Green chutney with curd । Quick recipe in just 2 min । 2 मिनट में बनने वाली हरी दही चटनी ।',
#   'Tags': ['#green chutney#dhania pudina chutney'],
#   'Thumbnail': 'https://i.ytimg.com/vi/V5j_koWHtlU/default.jpg',
#   'Description': 'Green chutney (with curd)is a versatile dip used for most of the roasted or fried dishes be it Indian,Asian or fusion cuisine.\nThey can accompany dishes like roasted chicken,chicken popcorns,nuggets or even Biryani and kebabs.\nThis green dip can used as a dressing to various salads as well.\nSo enjoy.❤️\n\nChicken Nuggets Recipe👇\nhttps://youtu.be/NYctUrW27Cg\n\nCheese Corn Balls Recipe👇\nhttps://youtu.be/zZekB4qZvLQ',
#   'Published_Date': '2020-07-11T07:51:14Z',
#   'Duration': 'PT1M55S',
#   'Views': '45',
#   'Comments': None,
#   'likes': '7',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': 'AoWu5hYGWgY',
#   'Title': 'Chilly Paneer Dry । Quick Recipe । चिल्ली पनीर ड्राई। जल्दी में बनाएं । आसानी से ।',
#   'Tags': ['#chilly#chilly Paneer dry#starter#paneer snacks'],
#   'Thumbnail': 'https://i.ytimg.com/vi/AoWu5hYGWgY/default.jpg',
#   'Description': 'A delectable veg appetizer.Dry chilly Paneer Starter Recipe.Juicy Paneer with crunchy coating stirred in hot n Sweet sauces.\nQuickly prepared with less ingredients easily available at home..A yummy n easy appetizer totally loved by one and all.',
#   'Published_Date': '2020-07-05T08:15:54Z',
#   'Duration': 'PT3M37S',
#   'Views': '68',
#   'Comments': None,
#   'likes': '14',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': 'fOE0rsNj1SI',
#   'Title': 'Banana Custard Cake । No Egg । No Butter । No condensed Milk । बनाना कस्टर्ड केक ।',
#   'Tags': ['#custard#cake#banana cake'],
#   'Thumbnail': 'https://i.ytimg.com/vi/fOE0rsNj1SI/default.jpg',
#   'Description': 'Banana cake with Custard spread.simple eggless and tasty recipe full of goodness of banana and Rich flavor of custard.\nA treat to your sweettooth.Eggless veg banana cake recipe.Moist and fluffy dessert.\n\nTry a quick 1 min cake recipe👇\nhttps://youtu.be/-Ld5tYaCzYg\n\nMango Glaze cake\nhttps://youtu.be/JCLn277Rk9U',
#   'Published_Date': '2020-06-22T20:20:12Z',
#   'Duration': 'PT5M22S',
#   'Views': '95',
#   'Comments': None,
#   'likes': '9',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': 'NYctUrW27Cg',
#   'Title': 'Tandoori Chicken Nuggets । तंदूरी चिकन नगेट्स।',
#   'Tags': ['#chicken snacks#chicken starter#tandoori'],
#   'Thumbnail': 'https://i.ytimg.com/vi/NYctUrW27Cg/default.jpg',
#   'Description': "Crunchy juicy chicken starter with a hint of desi spices.\nPerfect for monsoon.Delectebale fried Crispy chicken snack.Enjoyable with green chutney or ketchup.Presenting especially for Father's day.\n\nFind green Chutney recipe here: https://youtu.be/V5j_koWHtlU",
#   'Published_Date': '2020-06-21T05:51:56Z',
#   'Duration': 'PT4M52S',
#   'Views': '115',
#   'Comments': None,
#   'likes': '13',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': 'zZekB4qZvLQ',
#   'Title': 'Cheese Corn Balls । चीज़ कॉर्न बॉल्स।',
#   'Tags': ['#corn snacks#cheese corn'],
#   'Thumbnail': 'https://i.ytimg.com/vi/zZekB4qZvLQ/default.jpg',
#   'Description': 'An easy peesy corn snack recipe loved by all.Comfort snacking perfect to enjoy drizzle with.Cruncy outside and gooey inside.Worth giving a try.A perfect cheesy veg party starter.\n\nGreen curd Chutney Recipe👇\nhttps://youtu.be/V5j_koWHtlU',
#   'Published_Date': '2020-06-14T06:36:49Z',
#   'Duration': 'PT6M2S',
#   'Views': '61',
#   'Comments': None,
#   'likes': '13',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': 'BcelrTWW-6g',
#   'Title': "Tangy Mango Jellos | W'out gelatin | खट्टी मीठी आम की जेली कैंडी | बिना जिलेटिन के |",
#   'Tags': ['#mango#jelly#mango candy'],
#   'Thumbnail': 'https://i.ytimg.com/vi/BcelrTWW-6g/default.jpg',
#   'Description': 'Mango jello candies to beat this summer in yummy way.Simple n quick recipe equally liked by all age groups.\nEspecially loved by children.\nGive it a try n savour this flavorful Mango jello.',
#   'Published_Date': '2020-06-08T18:56:06Z',
#   'Duration': 'PT5M32S',
#   'Views': '78',
#   'Comments': None,
#   'likes': '11',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': 'tqlzPYAilTM',
#   'Title': 'No Yeast Garlic Bread | गार्लिक ब्रेड | बिना यीस्ट के |',
#   'Tags': ['#garlic#garlic bread'],
#   'Thumbnail': 'https://i.ytimg.com/vi/tqlzPYAilTM/default.jpg',
#   'Description': 'Garlic Breadsticks made without yeast.A yummy yet simple bread to snack on.\n\nSeeking fancy stuffed bread?Chk out my chicken stuffed bread recipe here👇\nhttps://youtu.be/xKUe7JD0Rx0',
#   'Published_Date': '2020-06-01T16:17:21Z',
#   'Duration': 'PT4M',
#   'Views': '138',
#   'Comments': None,
#   'likes': '14',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': 'xKUe7JD0Rx0',
#   'Title': 'Chicken Stuffed Bread without yeast | चिकन स्टफ्ड ब्रेड | यीस्ट के बिना |',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/xKUe7JD0Rx0/default.jpg',
#   'Description': 'A delectable snack perfect for your small hunger pangs.\nSimple yet delicious recipe with Rich looks n taste.Juicy chicken filled bread.A totally yum dish.\n\nVeg Zinger Parcel Dominos Style👇\nhttps://youtu.be/lAAtuK__rPU\n\nAlso check out No Yeast Garlic Bread👇\nhttps://youtu.be/tqlzPYAilTM',
#   'Published_Date': '2020-05-27T21:36:36Z',
#   'Duration': 'PT7M12S',
#   'Views': '123',
#   'Comments': None,
#   'likes': '14',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': '-Ld5tYaCzYg',
#   'Title': '1Min Mug Cake | No egg | 1 मिनट में कॉफी मग में केक बनाएं। एगलेस केक।',
#   'Tags': ['#mug cake#microwave snacks'],
#   'Thumbnail': 'https://i.ytimg.com/vi/-Ld5tYaCzYg/default.jpg',
#   'Description': 'Microwave Mug cake prepared in just a minute.Fluffy n moist mug cakes without eggs.\nPerfect for teensy weensy hunger pangs.\n\nRegular banana Custard cake👇\nhttps://youtu.be/fOE0rsNj1SI',
#   'Published_Date': '2020-05-26T13:33:15Z',
#   'Duration': 'PT5M2S',
#   'Views': '309',
#   'Comments': None,
#   'likes': '44',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Specxy Panda Bakes',
#   'Channel_Id': 'UCSXa6jwF7pvL-qVdS1OnytA',
#   'Video_Id': 'ZZTqDPVPDiw',
#   'Title': 'Watermelon Slush&Mojito | तरबूज स्लश और मोहिटो |',
#   'Tags': ['#slush#mojito#watermelon'],
#   'Thumbnail': 'https://i.ytimg.com/vi/ZZTqDPVPDiw/default.jpg',
#   'Description': 'Refreshing Watermelon Slushie and Mojito to sooth your souls this summer.',
#   'Published_Date': '2020-05-24T20:16:36Z',
#   'Duration': 'PT3M56S',
#   'Views': '88',
#   'Comments': None,
#   'likes': '12',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'}]

# %%
def comment_table():
    mydb = psycopg2.connect(
        host="localhost",
        user="postgres",
        password="roomno13",
        database="youtube_data",
        port="5432"
    )
    cursor = mydb.cursor()

    drop_query = "DROP TABLE IF EXISTS comments"
    cursor.execute(drop_query)
    mydb.commit()

   
    create_query = '''CREATE TABLE IF NOT EXISTS comments(Comment_Id varchar(100) primary key,
                                                          Video_Id varchar(80),
                                                          Comment_Text text,
                                                          Comment_Author varchar(150),
                                                          Comment_Published timestamp
                                                            )'''
    cursor.execute(create_query)
    mydb.commit()



    com_list = []  # Assuming this is defined elsewhere
    # Assuming `client` is defined elsewhere for MongoDB
    db = client["Youtube_data"]
    coll1 = db["channel_details"]
    for com_data in coll1.find({}, {"_id": 0,"comment_information": 1}):
        for i in range(len(com_data["comment_information"])):
            com_list.append(com_data["comment_information"][i])
    df3 = pd.DataFrame(com_list)

    for index, row in df3.iterrows():
        insert_query = '''INSERT INTO comments( Comment_Id,
                                                Video_Id,
                                                Comment_Text,
                                                Comment_Author,
                                                Comment_Published)
                                                VALUES (%s,%s,%s,%s,%s)
                                                ON CONFLICT (Comment_Id) DO NOTHING'''
        values = (
            row['Comment_Id'],
            row['Video_Id'],
            row.get('Comment_Text'),
            row.get('Comment_Author'),
            # row.get('Comment_Published'),
            row['Comment_Published']
                 )
        
        cursor.execute(insert_query,values)
        mydb.commit()
  
comment_table()
# Out:
# ---------------------------------------------------------------------------
# DatatypeMismatch                          Traceback (most recent call last)
# Cell In[57], line 56
#      53         cursor.execute(insert_query,values)
#      54         mydb.commit()
# ---> 56 comment_table()
#
# Cell In[57], line 53, in comment_table()
#      37 insert_query = '''INSERT INTO comments( Comment_Id,
#      38                                         Video_Id,
#      39                                         Comment_Text,
#    (...)
#      42                                         VALUES (%s,%s,%s,%s,%s)
#      43                                         ON CONFLICT (Comment_Id) DO NOTHING'''
#      44 values = (
#      45     row['Comment_Id'],
#      46     row['Video_Id'],
#    (...)
#      50     row['Comment_Published']
#      51          )
# ---> 53 cursor.execute(insert_query,values)
#      54 mydb.commit()
#
# DatatypeMismatch: column "comment_published" is of type timestamp without time zone but expression is of type double precision
# LINE 6: ...F4AaABAg','m-70-JuGjJg','NaN'::float,'NaN'::float,'NaN'::flo...
#                                                              ^
# HINT:  You will need to rewrite or cast the expression.

# %%
com_list = []  # Assuming this is defined elsewhere
    # Assuming `client` is defined elsewhere for MongoDB
db = client["Youtube_data"]
coll1 = db["channel_details"]
for com_data in coll1.find({}, {"_id": 0,"comment_information": 1}):
    for i in range(len(com_data["comment_information"])):
        com_list.append(com_data["comment_information"][i])

# %%
com_list
# Out:
# [{'Comment_Id': 'UgxD7uusQqcMma3d8gF4AaABAg',
#   'Video_Id': 'm-70-JuGjJg',
#   'Comment_text': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': 'm-70-JuGjJg',
#    'textDisplay': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#    'textOriginal': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.\nThe  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️\n\nWaiting for more🌼',
#    'authorDisplayName': '@shrutibudh9543',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/hVbtighBNG-GaGJN0mYvavBROu7ff6PkrbaSesv60D9MJ-nKXkulAr8sBdgmrlM3S1I7Ye37=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@shrutibudh9543',
#    'authorChannelId': {'value': 'UC29mr9by3gx28j2LppEEP7A'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 12,
#    'publishedAt': '2023-09-27T17:49:22Z',
#    'updatedAt': '2023-09-27T17:49:22Z'},
#   'Comment_published': '2023-09-27T17:49:22Z'},
#  {'Comment_Id': 'UgxD7uusQqcMma3d8gF4AaABAg',
#   'Video_Id': 'm-70-JuGjJg',
#   'Comment_text': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': 'm-70-JuGjJg',
#    'textDisplay': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#    'textOriginal': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.\nThe  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️\n\nWaiting for more🌼',
#    'authorDisplayName': '@shrutibudh9543',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/hVbtighBNG-GaGJN0mYvavBROu7ff6PkrbaSesv60D9MJ-nKXkulAr8sBdgmrlM3S1I7Ye37=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@shrutibudh9543',
#    'authorChannelId': {'value': 'UC29mr9by3gx28j2LppEEP7A'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 12,
#    'publishedAt': '2023-09-27T17:49:22Z',
#    'updatedAt': '2023-09-27T17:49:22Z'},
#   'Comment_published': '2023-09-27T17:49:22Z'},
#  {'Comment_Id': 'UgxD7uusQqcMma3d8gF4AaABAg',
#   'Video_Id': 'm-70-JuGjJg',
#   'Comment_text': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': 'm-70-JuGjJg',
#    'textDisplay': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#    'textOriginal': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.\nThe  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️\n\nWaiting for more🌼',
#    'authorDisplayName': '@shrutibudh9543',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/hVbtighBNG-GaGJN0mYvavBROu7ff6PkrbaSesv60D9MJ-nKXkulAr8sBdgmrlM3S1I7Ye37=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@shrutibudh9543',
#    'authorChannelId': {'value': 'UC29mr9by3gx28j2LppEEP7A'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 12,
#    'publishedAt': '2023-09-27T17:49:22Z',
#    'updatedAt': '2023-09-27T17:49:22Z'},
#   'Comment_published': '2023-09-27T17:49:22Z'},
#  {'Comment_Id': 'UgxD7uusQqcMma3d8gF4AaABAg',
#   'Video_Id': 'm-70-JuGjJg',
#   'Comment_text': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': 'm-70-JuGjJg',
#    'textDisplay': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#    'textOriginal': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.\nThe  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️\n\nWaiting for more🌼',
#    'authorDisplayName': '@shrutibudh9543',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/hVbtighBNG-GaGJN0mYvavBROu7ff6PkrbaSesv60D9MJ-nKXkulAr8sBdgmrlM3S1I7Ye37=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@shrutibudh9543',
#    'authorChannelId': {'value': 'UC29mr9by3gx28j2LppEEP7A'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 12,
#    'publishedAt': '2023-09-27T17:49:22Z',
#    'updatedAt': '2023-09-27T17:49:22Z'},
#   'Comment_published': '2023-09-27T17:49:22Z'},
#  {'Comment_Id': 'UgxD7uusQqcMma3d8gF4AaABAg',
#   'Video_Id': 'm-70-JuGjJg',
#   'Comment_text': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': 'm-70-JuGjJg',
#    'textDisplay': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#    'textOriginal': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.\nThe  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️\n\nWaiting for more🌼',
#    'authorDisplayName': '@shrutibudh9543',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/hVbtighBNG-GaGJN0mYvavBROu7ff6PkrbaSesv60D9MJ-nKXkulAr8sBdgmrlM3S1I7Ye37=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@shrutibudh9543',
#    'authorChannelId': {'value': 'UC29mr9by3gx28j2LppEEP7A'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 12,
#    'publishedAt': '2023-09-27T17:49:22Z',
#    'updatedAt': '2023-09-27T17:49:22Z'},
#   'Comment_published': '2023-09-27T17:49:22Z'},
#  {'Comment_Id': 'UgxD7uusQqcMma3d8gF4AaABAg',
#   'Video_Id': 'm-70-JuGjJg',
#   'Comment_text': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': 'm-70-JuGjJg',
#    'textDisplay': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#    'textOriginal': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.\nThe  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️\n\nWaiting for more🌼',
#    'authorDisplayName': '@shrutibudh9543',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/hVbtighBNG-GaGJN0mYvavBROu7ff6PkrbaSesv60D9MJ-nKXkulAr8sBdgmrlM3S1I7Ye37=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@shrutibudh9543',
#    'authorChannelId': {'value': 'UC29mr9by3gx28j2LppEEP7A'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 12,
#    'publishedAt': '2023-09-27T17:49:22Z',
#    'updatedAt': '2023-09-27T17:49:22Z'},
#   'Comment_published': '2023-09-27T17:49:22Z'},
#  {'Comment_Id': 'UgxD7uusQqcMma3d8gF4AaABAg',
#   'Video_Id': 'm-70-JuGjJg',
#   'Comment_text': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': 'm-70-JuGjJg',
#    'textDisplay': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#    'textOriginal': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.\nThe  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️\n\nWaiting for more🌼',
#    'authorDisplayName': '@shrutibudh9543',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/hVbtighBNG-GaGJN0mYvavBROu7ff6PkrbaSesv60D9MJ-nKXkulAr8sBdgmrlM3S1I7Ye37=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@shrutibudh9543',
#    'authorChannelId': {'value': 'UC29mr9by3gx28j2LppEEP7A'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 12,
#    'publishedAt': '2023-09-27T17:49:22Z',
#    'updatedAt': '2023-09-27T17:49:22Z'},
#   'Comment_published': '2023-09-27T17:49:22Z'},
#  {'Comment_Id': 'UgxD7uusQqcMma3d8gF4AaABAg',
#   'Video_Id': 'm-70-JuGjJg',
#   'Comment_text': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': 'm-70-JuGjJg',
#    'textDisplay': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#    'textOriginal': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.\nThe  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️\n\nWaiting for more🌼',
#    'authorDisplayName': '@shrutibudh9543',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/hVbtighBNG-GaGJN0mYvavBROu7ff6PkrbaSesv60D9MJ-nKXkulAr8sBdgmrlM3S1I7Ye37=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@shrutibudh9543',
#    'authorChannelId': {'value': 'UC29mr9by3gx28j2LppEEP7A'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 12,
#    'publishedAt': '2023-09-27T17:49:22Z',
#    'updatedAt': '2023-09-27T17:49:22Z'},
#   'Comment_published': '2023-09-27T17:49:22Z'},
#  {'Comment_Id': 'UgxD7uusQqcMma3d8gF4AaABAg',
#   'Video_Id': 'm-70-JuGjJg',
#   'Comment_text': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': 'm-70-JuGjJg',
#    'textDisplay': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#    'textOriginal': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.\nThe  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️\n\nWaiting for more🌼',
#    'authorDisplayName': '@shrutibudh9543',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/hVbtighBNG-GaGJN0mYvavBROu7ff6PkrbaSesv60D9MJ-nKXkulAr8sBdgmrlM3S1I7Ye37=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@shrutibudh9543',
#    'authorChannelId': {'value': 'UC29mr9by3gx28j2LppEEP7A'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 12,
#    'publishedAt': '2023-09-27T17:49:22Z',
#    'updatedAt': '2023-09-27T17:49:22Z'},
#   'Comment_published': '2023-09-27T17:49:22Z'},
#  {'Comment_Id': 'UgxD7uusQqcMma3d8gF4AaABAg',
#   'Video_Id': 'm-70-JuGjJg',
#   'Comment_text': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': 'm-70-JuGjJg',
#    'textDisplay': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#    'textOriginal': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.\nThe  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️\n\nWaiting for more🌼',
#    'authorDisplayName': '@shrutibudh9543',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/hVbtighBNG-GaGJN0mYvavBROu7ff6PkrbaSesv60D9MJ-nKXkulAr8sBdgmrlM3S1I7Ye37=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@shrutibudh9543',
#    'authorChannelId': {'value': 'UC29mr9by3gx28j2LppEEP7A'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 12,
#    'publishedAt': '2023-09-27T17:49:22Z',
#    'updatedAt': '2023-09-27T17:49:22Z'},
#   'Comment_published': '2023-09-27T17:49:22Z'},
#  {'Comment_Id': 'UgxD7uusQqcMma3d8gF4AaABAg',
#   'Video_Id': 'm-70-JuGjJg',
#   'Comment_text': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': 'm-70-JuGjJg',
#    'textDisplay': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#    'textOriginal': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.\nThe  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️\n\nWaiting for more🌼',
#    'authorDisplayName': '@shrutibudh9543',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/hVbtighBNG-GaGJN0mYvavBROu7ff6PkrbaSesv60D9MJ-nKXkulAr8sBdgmrlM3S1I7Ye37=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@shrutibudh9543',
#    'authorChannelId': {'value': 'UC29mr9by3gx28j2LppEEP7A'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 12,
#    'publishedAt': '2023-09-27T17:49:22Z',
#    'updatedAt': '2023-09-27T17:49:22Z'},
#   'Comment_published': '2023-09-27T17:49:22Z'},
#  {'Comment_Id': 'UgxD7uusQqcMma3d8gF4AaABAg',
#   'Video_Id': 'm-70-JuGjJg',
#   'Comment_text': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': 'm-70-JuGjJg',
#    'textDisplay': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#    'textOriginal': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.\nThe  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️\n\nWaiting for more🌼',
#    'authorDisplayName': '@shrutibudh9543',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/hVbtighBNG-GaGJN0mYvavBROu7ff6PkrbaSesv60D9MJ-nKXkulAr8sBdgmrlM3S1I7Ye37=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@shrutibudh9543',
#    'authorChannelId': {'value': 'UC29mr9by3gx28j2LppEEP7A'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 12,
#    'publishedAt': '2023-09-27T17:49:22Z',
#    'updatedAt': '2023-09-27T17:49:22Z'},
#   'Comment_published': '2023-09-27T17:49:22Z'},
#  {'Comment_Id': 'UgxD7uusQqcMma3d8gF4AaABAg',
#   'Video_Id': 'm-70-JuGjJg',
#   'Comment_text': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': 'm-70-JuGjJg',
#    'textDisplay': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#    'textOriginal': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.\nThe  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️\n\nWaiting for more🌼',
#    'authorDisplayName': '@shrutibudh9543',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/hVbtighBNG-GaGJN0mYvavBROu7ff6PkrbaSesv60D9MJ-nKXkulAr8sBdgmrlM3S1I7Ye37=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@shrutibudh9543',
#    'authorChannelId': {'value': 'UC29mr9by3gx28j2LppEEP7A'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 12,
#    'publishedAt': '2023-09-27T17:49:22Z',
#    'updatedAt': '2023-09-27T17:49:22Z'},
#   'Comment_published': '2023-09-27T17:49:22Z'},
#  {'Comment_Id': 'UgxD7uusQqcMma3d8gF4AaABAg',
#   'Video_Id': 'm-70-JuGjJg',
#   'Comment_text': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': 'm-70-JuGjJg',
#    'textDisplay': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#    'textOriginal': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.\nThe  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️\n\nWaiting for more🌼',
#    'authorDisplayName': '@shrutibudh9543',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/hVbtighBNG-GaGJN0mYvavBROu7ff6PkrbaSesv60D9MJ-nKXkulAr8sBdgmrlM3S1I7Ye37=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@shrutibudh9543',
#    'authorChannelId': {'value': 'UC29mr9by3gx28j2LppEEP7A'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 12,
#    'publishedAt': '2023-09-27T17:49:22Z',
#    'updatedAt': '2023-09-27T17:49:22Z'},
#   'Comment_published': '2023-09-27T17:49:22Z'},
#  {'Comment_Id': 'UgxD7uusQqcMma3d8gF4AaABAg',
#   'Video_Id': 'm-70-JuGjJg',
#   'Comment_text': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': 'm-70-JuGjJg',
#    'textDisplay': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#    'textOriginal': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.\nThe  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️\n\nWaiting for more🌼',
#    'authorDisplayName': '@shrutibudh9543',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/hVbtighBNG-GaGJN0mYvavBROu7ff6PkrbaSesv60D9MJ-nKXkulAr8sBdgmrlM3S1I7Ye37=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@shrutibudh9543',
#    'authorChannelId': {'value': 'UC29mr9by3gx28j2LppEEP7A'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 12,
#    'publishedAt': '2023-09-27T17:49:22Z',
#    'updatedAt': '2023-09-27T17:49:22Z'},
#   'Comment_published': '2023-09-27T17:49:22Z'},
#  {'Comment_Id': 'UgxD7uusQqcMma3d8gF4AaABAg',
#   'Video_Id': 'm-70-JuGjJg',
#   'Comment_text': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': 'm-70-JuGjJg',
#    'textDisplay': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#    'textOriginal': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.\nThe  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️\n\nWaiting for more🌼',
#    'authorDisplayName': '@shrutibudh9543',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/hVbtighBNG-GaGJN0mYvavBROu7ff6PkrbaSesv60D9MJ-nKXkulAr8sBdgmrlM3S1I7Ye37=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@shrutibudh9543',
#    'authorChannelId': {'value': 'UC29mr9by3gx28j2LppEEP7A'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 12,
#    'publishedAt': '2023-09-27T17:49:22Z',
#    'updatedAt': '2023-09-27T17:49:22Z'},
#   'Comment_published': '2023-09-27T17:49:22Z'},
#  {'Comment_Id': 'UgxD7uusQqcMma3d8gF4AaABAg',
#   'Video_Id': 'm-70-JuGjJg',
#   'Comment_text': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': 'm-70-JuGjJg',
#    'textDisplay': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#    'textOriginal': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.\nThe  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️\n\nWaiting for more🌼',
#    'authorDisplayName': '@shrutibudh9543',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/hVbtighBNG-GaGJN0mYvavBROu7ff6PkrbaSesv60D9MJ-nKXkulAr8sBdgmrlM3S1I7Ye37=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@shrutibudh9543',
#    'authorChannelId': {'value': 'UC29mr9by3gx28j2LppEEP7A'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 12,
#    'publishedAt': '2023-09-27T17:49:22Z',
#    'updatedAt': '2023-09-27T17:49:22Z'},
#   'Comment_published': '2023-09-27T17:49:22Z'},
#  {'Comment_Id': 'UgxD7uusQqcMma3d8gF4AaABAg',
#   'Video_Id': 'm-70-JuGjJg',
#   'Comment_text': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': 'm-70-JuGjJg',
#    'textDisplay': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#    'textOriginal': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.\nThe  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️\n\nWaiting for more🌼',
#    'authorDisplayName': '@shrutibudh9543',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/hVbtighBNG-GaGJN0mYvavBROu7ff6PkrbaSesv60D9MJ-nKXkulAr8sBdgmrlM3S1I7Ye37=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@shrutibudh9543',
#    'authorChannelId': {'value': 'UC29mr9by3gx28j2LppEEP7A'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 12,
#    'publishedAt': '2023-09-27T17:49:22Z',
#    'updatedAt': '2023-09-27T17:49:22Z'},
#   'Comment_published': '2023-09-27T17:49:22Z'},
#  {'Comment_Id': 'UgxD7uusQqcMma3d8gF4AaABAg',
#   'Video_Id': 'm-70-JuGjJg',
#   'Comment_text': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': 'm-70-JuGjJg',
#    'textDisplay': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#    'textOriginal': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.\nThe  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️\n\nWaiting for more🌼',
#    'authorDisplayName': '@shrutibudh9543',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/hVbtighBNG-GaGJN0mYvavBROu7ff6PkrbaSesv60D9MJ-nKXkulAr8sBdgmrlM3S1I7Ye37=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@shrutibudh9543',
#    'authorChannelId': {'value': 'UC29mr9by3gx28j2LppEEP7A'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 12,
#    'publishedAt': '2023-09-27T17:49:22Z',
#    'updatedAt': '2023-09-27T17:49:22Z'},
#   'Comment_published': '2023-09-27T17:49:22Z'},
#  {'Comment_Id': 'UgxD7uusQqcMma3d8gF4AaABAg',
#   'Video_Id': 'm-70-JuGjJg',
#   'Comment_text': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': 'm-70-JuGjJg',
#    'textDisplay': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#    'textOriginal': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.\nThe  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️\n\nWaiting for more🌼',
#    'authorDisplayName': '@shrutibudh9543',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/hVbtighBNG-GaGJN0mYvavBROu7ff6PkrbaSesv60D9MJ-nKXkulAr8sBdgmrlM3S1I7Ye37=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@shrutibudh9543',
#    'authorChannelId': {'value': 'UC29mr9by3gx28j2LppEEP7A'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 12,
#    'publishedAt': '2023-09-27T17:49:22Z',
#    'updatedAt': '2023-09-27T17:49:22Z'},
#   'Comment_published': '2023-09-27T17:49:22Z'},
#  {'Comment_Id': 'UgxD7uusQqcMma3d8gF4AaABAg',
#   'Video_Id': 'm-70-JuGjJg',
#   'Comment_text': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': 'm-70-JuGjJg',
#    'textDisplay': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#    'textOriginal': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.\nThe  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️\n\nWaiting for more🌼',
#    'authorDisplayName': '@shrutibudh9543',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/hVbtighBNG-GaGJN0mYvavBROu7ff6PkrbaSesv60D9MJ-nKXkulAr8sBdgmrlM3S1I7Ye37=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@shrutibudh9543',
#    'authorChannelId': {'value': 'UC29mr9by3gx28j2LppEEP7A'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 12,
#    'publishedAt': '2023-09-27T17:49:22Z',
#    'updatedAt': '2023-09-27T17:49:22Z'},
#   'Comment_published': '2023-09-27T17:49:22Z'},
#  {'Comment_Id': 'UgxD7uusQqcMma3d8gF4AaABAg',
#   'Video_Id': 'm-70-JuGjJg',
#   'Comment_text': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': 'm-70-JuGjJg',
#    'textDisplay': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#    'textOriginal': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.\nThe  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️\n\nWaiting for more🌼',
#    'authorDisplayName': '@shrutibudh9543',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/hVbtighBNG-GaGJN0mYvavBROu7ff6PkrbaSesv60D9MJ-nKXkulAr8sBdgmrlM3S1I7Ye37=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@shrutibudh9543',
#    'authorChannelId': {'value': 'UC29mr9by3gx28j2LppEEP7A'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 12,
#    'publishedAt': '2023-09-27T17:49:22Z',
#    'updatedAt': '2023-09-27T17:49:22Z'},
#   'Comment_published': '2023-09-27T17:49:22Z'},
#  {'Comment_Id': 'UgxD7uusQqcMma3d8gF4AaABAg',
#   'Video_Id': 'm-70-JuGjJg',
#   'Comment_text': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': 'm-70-JuGjJg',
#    'textDisplay': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#    'textOriginal': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.\nThe  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️\n\nWaiting for more🌼',
#    'authorDisplayName': '@shrutibudh9543',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/hVbtighBNG-GaGJN0mYvavBROu7ff6PkrbaSesv60D9MJ-nKXkulAr8sBdgmrlM3S1I7Ye37=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@shrutibudh9543',
#    'authorChannelId': {'value': 'UC29mr9by3gx28j2LppEEP7A'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 12,
#    'publishedAt': '2023-09-27T17:49:22Z',
#    'updatedAt': '2023-09-27T17:49:22Z'},
#   'Comment_published': '2023-09-27T17:49:22Z'},
#  {'Comment_Id': 'UgxD7uusQqcMma3d8gF4AaABAg',
#   'Video_Id': 'm-70-JuGjJg',
#   'Comment_text': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': 'm-70-JuGjJg',
#    'textDisplay': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#    'textOriginal': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.\nThe  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️\n\nWaiting for more🌼',
#    'authorDisplayName': '@shrutibudh9543',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/hVbtighBNG-GaGJN0mYvavBROu7ff6PkrbaSesv60D9MJ-nKXkulAr8sBdgmrlM3S1I7Ye37=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@shrutibudh9543',
#    'authorChannelId': {'value': 'UC29mr9by3gx28j2LppEEP7A'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 12,
#    'publishedAt': '2023-09-27T17:49:22Z',
#    'updatedAt': '2023-09-27T17:49:22Z'},
#   'Comment_published': '2023-09-27T17:49:22Z'},
#  {'Comment_Id': 'UgxD7uusQqcMma3d8gF4AaABAg',
#   'Video_Id': 'm-70-JuGjJg',
#   'Comment_text': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': 'm-70-JuGjJg',
#    'textDisplay': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#    'textOriginal': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.\nThe  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️\n\nWaiting for more🌼',
#    'authorDisplayName': '@shrutibudh9543',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/hVbtighBNG-GaGJN0mYvavBROu7ff6PkrbaSesv60D9MJ-nKXkulAr8sBdgmrlM3S1I7Ye37=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@shrutibudh9543',
#    'authorChannelId': {'value': 'UC29mr9by3gx28j2LppEEP7A'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 12,
#    'publishedAt': '2023-09-27T17:49:22Z',
#    'updatedAt': '2023-09-27T17:49:22Z'},
#   'Comment_published': '2023-09-27T17:49:22Z'},
#  {'Comment_Id': 'UgxD7uusQqcMma3d8gF4AaABAg',
#   'Video_Id': 'm-70-JuGjJg',
#   'Comment_text': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': 'm-70-JuGjJg',
#    'textDisplay': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#    'textOriginal': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.\nThe  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️\n\nWaiting for more🌼',
#    'authorDisplayName': '@shrutibudh9543',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/hVbtighBNG-GaGJN0mYvavBROu7ff6PkrbaSesv60D9MJ-nKXkulAr8sBdgmrlM3S1I7Ye37=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@shrutibudh9543',
#    'authorChannelId': {'value': 'UC29mr9by3gx28j2LppEEP7A'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 12,
#    'publishedAt': '2023-09-27T17:49:22Z',
#    'updatedAt': '2023-09-27T17:49:22Z'},
#   'Comment_published': '2023-09-27T17:49:22Z'},
#  {'Comment_Id': 'UgxD7uusQqcMma3d8gF4AaABAg',
#   'Video_Id': 'm-70-JuGjJg',
#   'Comment_text': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': 'm-70-JuGjJg',
#    'textDisplay': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#    'textOriginal': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.\nThe  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️\n\nWaiting for more🌼',
#    'authorDisplayName': '@shrutibudh9543',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/hVbtighBNG-GaGJN0mYvavBROu7ff6PkrbaSesv60D9MJ-nKXkulAr8sBdgmrlM3S1I7Ye37=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@shrutibudh9543',
#    'authorChannelId': {'value': 'UC29mr9by3gx28j2LppEEP7A'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 12,
#    'publishedAt': '2023-09-27T17:49:22Z',
#    'updatedAt': '2023-09-27T17:49:22Z'},
#   'Comment_published': '2023-09-27T17:49:22Z'},
#  {'Comment_Id': 'UgxD7uusQqcMma3d8gF4AaABAg',
#   'Video_Id': 'm-70-JuGjJg',
#   'Comment_text': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': 'm-70-JuGjJg',
#    'textDisplay': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#    'textOriginal': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.\nThe  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️\n\nWaiting for more🌼',
#    'authorDisplayName': '@shrutibudh9543',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/hVbtighBNG-GaGJN0mYvavBROu7ff6PkrbaSesv60D9MJ-nKXkulAr8sBdgmrlM3S1I7Ye37=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@shrutibudh9543',
#    'authorChannelId': {'value': 'UC29mr9by3gx28j2LppEEP7A'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 12,
#    'publishedAt': '2023-09-27T17:49:22Z',
#    'updatedAt': '2023-09-27T17:49:22Z'},
#   'Comment_published': '2023-09-27T17:49:22Z'},
#  {'Comment_Id': 'UgxD7uusQqcMma3d8gF4AaABAg',
#   'Video_Id': 'm-70-JuGjJg',
#   'Comment_text': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': 'm-70-JuGjJg',
#    'textDisplay': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#    'textOriginal': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.\nThe  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️\n\nWaiting for more🌼',
#    'authorDisplayName': '@shrutibudh9543',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/hVbtighBNG-GaGJN0mYvavBROu7ff6PkrbaSesv60D9MJ-nKXkulAr8sBdgmrlM3S1I7Ye37=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@shrutibudh9543',
#    'authorChannelId': {'value': 'UC29mr9by3gx28j2LppEEP7A'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 12,
#    'publishedAt': '2023-09-27T17:49:22Z',
#    'updatedAt': '2023-09-27T17:49:22Z'},
#   'Comment_published': '2023-09-27T17:49:22Z'},
#  {'Comment_Id': 'UgxD7uusQqcMma3d8gF4AaABAg',
#   'Video_Id': 'm-70-JuGjJg',
#   'Comment_text': 'This is impressive 👏🏾👏🏾👏🏾 Congratulations to the entire team..the actors, the singers and the video itself feels so natural and well executed.<br>The  song ofcourse has its own charm ✨ and the video has such freshness and refinement to it...will be watching it for hrs❤️<br><br>Waiting for more🌼',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': 'm-70-JuGjJg',
# ...
#    'authorChannelId': {'value': 'UCgmVBvJGKoM-Owqj04r0z8A'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2022-09-27T04:38:19Z',
#    'updatedAt': '2022-09-27T04:38:19Z'},
#   'Comment_published': '2022-09-27T04:38:19Z'},
#  {'Comment_Id': 'UgxKfMQjzD0asf299GZ4AaABAg',
#   'Video_Id': 'm0earX1Qw08',
#   'Comment_text': 'Bro can u recreate it with fast music as per ur style...i guess it will be awesome......can u try.',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': 'm0earX1Qw08',
#    'textDisplay': 'Bro can u recreate it with fast music as per ur style...i guess it will be awesome......can u try.',
#    'textOriginal': 'Bro can u recreate it with fast music as per ur style...i guess it will be awesome......can u try.',
#    'authorDisplayName': '@raviranjantoppo8648',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/9cn6eHlw0HQgibJtwJMutC-KIc0F_7OLzJ0PH7WuuX3I3cdJOzGlejT_tummxC1rifPC2U1-IQ=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@raviranjantoppo8648',
#    'authorChannelId': {'value': 'UCgmVBvJGKoM-Owqj04r0z8A'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2022-09-27T04:38:19Z',
#    'updatedAt': '2022-09-27T04:38:19Z'},
#   'Comment_published': '2022-09-27T04:38:19Z'},
#  {'Comment_Id': 'UgyTkicHxNTy_-9IQxR4AaABAg',
#   'Video_Id': '1LRZSTkJCs4',
#   'Comment_text': '💗🥺',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': '1LRZSTkJCs4',
#    'textDisplay': '💗🥺',
#    'textOriginal': '💗🥺',
#    'authorDisplayName': '@nidhitirkyyyy6610',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_l137uOofY0p5fVz-5gjIbyAIQF3nxsJboLYjU-xu0qSHMuWkWsB0e2PhOW65tsS3u8ig=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@nidhitirkyyyy6610',
#    'authorChannelId': {'value': 'UCTURz1mqoOTEfbUsnXwKmLw'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2022-10-23T10:54:25Z',
#    'updatedAt': '2022-10-23T10:54:25Z'},
#   'Comment_published': '2022-10-23T10:54:25Z'},
#  {'Comment_Id': 'UgyTkicHxNTy_-9IQxR4AaABAg',
#   'Video_Id': '1LRZSTkJCs4',
#   'Comment_text': '💗🥺',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': '1LRZSTkJCs4',
#    'textDisplay': '💗🥺',
#    'textOriginal': '💗🥺',
#    'authorDisplayName': '@nidhitirkyyyy6610',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_l137uOofY0p5fVz-5gjIbyAIQF3nxsJboLYjU-xu0qSHMuWkWsB0e2PhOW65tsS3u8ig=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@nidhitirkyyyy6610',
#    'authorChannelId': {'value': 'UCTURz1mqoOTEfbUsnXwKmLw'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2022-10-23T10:54:25Z',
#    'updatedAt': '2022-10-23T10:54:25Z'},
#   'Comment_published': '2022-10-23T10:54:25Z'},
#  {'Comment_Id': 'UgyTkicHxNTy_-9IQxR4AaABAg',
#   'Video_Id': '1LRZSTkJCs4',
#   'Comment_text': '💗🥺',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': '1LRZSTkJCs4',
#    'textDisplay': '💗🥺',
#    'textOriginal': '💗🥺',
#    'authorDisplayName': '@nidhitirkyyyy6610',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_l137uOofY0p5fVz-5gjIbyAIQF3nxsJboLYjU-xu0qSHMuWkWsB0e2PhOW65tsS3u8ig=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@nidhitirkyyyy6610',
#    'authorChannelId': {'value': 'UCTURz1mqoOTEfbUsnXwKmLw'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2022-10-23T10:54:25Z',
#    'updatedAt': '2022-10-23T10:54:25Z'},
#   'Comment_published': '2022-10-23T10:54:25Z'},
#  {'Comment_Id': 'UgyTkicHxNTy_-9IQxR4AaABAg',
#   'Video_Id': '1LRZSTkJCs4',
#   'Comment_text': '💗🥺',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': '1LRZSTkJCs4',
#    'textDisplay': '💗🥺',
#    'textOriginal': '💗🥺',
#    'authorDisplayName': '@nidhitirkyyyy6610',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_l137uOofY0p5fVz-5gjIbyAIQF3nxsJboLYjU-xu0qSHMuWkWsB0e2PhOW65tsS3u8ig=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@nidhitirkyyyy6610',
#    'authorChannelId': {'value': 'UCTURz1mqoOTEfbUsnXwKmLw'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2022-10-23T10:54:25Z',
#    'updatedAt': '2022-10-23T10:54:25Z'},
#   'Comment_published': '2022-10-23T10:54:25Z'},
#  {'Comment_Id': 'UgyTkicHxNTy_-9IQxR4AaABAg',
#   'Video_Id': '1LRZSTkJCs4',
#   'Comment_text': '💗🥺',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': '1LRZSTkJCs4',
#    'textDisplay': '💗🥺',
#    'textOriginal': '💗🥺',
#    'authorDisplayName': '@nidhitirkyyyy6610',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_l137uOofY0p5fVz-5gjIbyAIQF3nxsJboLYjU-xu0qSHMuWkWsB0e2PhOW65tsS3u8ig=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@nidhitirkyyyy6610',
#    'authorChannelId': {'value': 'UCTURz1mqoOTEfbUsnXwKmLw'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2022-10-23T10:54:25Z',
#    'updatedAt': '2022-10-23T10:54:25Z'},
#   'Comment_published': '2022-10-23T10:54:25Z'},
#  {'Comment_Id': 'UgyTkicHxNTy_-9IQxR4AaABAg',
#   'Video_Id': '1LRZSTkJCs4',
#   'Comment_text': '💗🥺',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': '1LRZSTkJCs4',
#    'textDisplay': '💗🥺',
#    'textOriginal': '💗🥺',
#    'authorDisplayName': '@nidhitirkyyyy6610',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_l137uOofY0p5fVz-5gjIbyAIQF3nxsJboLYjU-xu0qSHMuWkWsB0e2PhOW65tsS3u8ig=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@nidhitirkyyyy6610',
#    'authorChannelId': {'value': 'UCTURz1mqoOTEfbUsnXwKmLw'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2022-10-23T10:54:25Z',
#    'updatedAt': '2022-10-23T10:54:25Z'},
#   'Comment_published': '2022-10-23T10:54:25Z'},
#  {'Comment_Id': 'Ugw9475hMzraXA2tNKR4AaABAg',
#   'Video_Id': '1duX0i5rPBY',
#   'Comment_text': 'Nice editing',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': '1duX0i5rPBY',
#    'textDisplay': 'Nice editing',
#    'textOriginal': 'Nice editing',
#    'authorDisplayName': '@mandeepminz5363',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ptGiburs0dlko_3D3CrACTkPk_oSa7xAgGYhB8Nhp5XRxc4FOfJ39gVzDnNE7lguboO37bwJuA=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@mandeepminz5363',
#    'authorChannelId': {'value': 'UCIYWNchxViTOZn7cPOCq3Kw'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2022-01-11T10:23:31Z',
#    'updatedAt': '2022-01-11T10:23:31Z'},
#   'Comment_published': '2022-01-11T10:23:31Z'},
#  {'Comment_Id': 'Ugw9475hMzraXA2tNKR4AaABAg',
#   'Video_Id': '1duX0i5rPBY',
#   'Comment_text': 'Nice editing',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': '1duX0i5rPBY',
#    'textDisplay': 'Nice editing',
#    'textOriginal': 'Nice editing',
#    'authorDisplayName': '@mandeepminz5363',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ptGiburs0dlko_3D3CrACTkPk_oSa7xAgGYhB8Nhp5XRxc4FOfJ39gVzDnNE7lguboO37bwJuA=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@mandeepminz5363',
#    'authorChannelId': {'value': 'UCIYWNchxViTOZn7cPOCq3Kw'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2022-01-11T10:23:31Z',
#    'updatedAt': '2022-01-11T10:23:31Z'},
#   'Comment_published': '2022-01-11T10:23:31Z'},
#  {'Comment_Id': 'Ugw9475hMzraXA2tNKR4AaABAg',
#   'Video_Id': '1duX0i5rPBY',
#   'Comment_text': 'Nice editing',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': '1duX0i5rPBY',
#    'textDisplay': 'Nice editing',
#    'textOriginal': 'Nice editing',
#    'authorDisplayName': '@mandeepminz5363',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ptGiburs0dlko_3D3CrACTkPk_oSa7xAgGYhB8Nhp5XRxc4FOfJ39gVzDnNE7lguboO37bwJuA=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@mandeepminz5363',
#    'authorChannelId': {'value': 'UCIYWNchxViTOZn7cPOCq3Kw'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2022-01-11T10:23:31Z',
#    'updatedAt': '2022-01-11T10:23:31Z'},
#   'Comment_published': '2022-01-11T10:23:31Z'},
#  {'Comment_Id': 'Ugw9475hMzraXA2tNKR4AaABAg',
#   'Video_Id': '1duX0i5rPBY',
#   'Comment_text': 'Nice editing',
#   'Comment_author': {'channelId': 'UCoC4TYHD1zDUYGmY59_5LCQ',
#    'videoId': '1duX0i5rPBY',
#    'textDisplay': 'Nice editing',
#    'textOriginal': 'Nice editing',
#    'authorDisplayName': '@mandeepminz5363',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ptGiburs0dlko_3D3CrACTkPk_oSa7xAgGYhB8Nhp5XRxc4FOfJ39gVzDnNE7lguboO37bwJuA=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@mandeepminz5363',
#    'authorChannelId': {'value': 'UCIYWNchxViTOZn7cPOCq3Kw'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2022-01-11T10:23:31Z',
#    'updatedAt': '2022-01-11T10:23:31Z'},
#   'Comment_published': '2022-01-11T10:23:31Z'},
#  {'Comment_Id': 'UgyE3uvjveEQk0UdJdt4AaABAg',
#   'Video_Id': 'mS6rkYWMVJI',
#   'Comment_text': 'Wow this is serious! Seriously amazing! ❤',
#   'Comment_author': {'channelId': 'UCMwu5UL4nfp7upkIdr0dtWg',
#    'videoId': 'mS6rkYWMVJI',
#    'textDisplay': 'Wow this is serious! Seriously amazing! ❤',
#    'textOriginal': 'Wow this is serious! Seriously amazing! ❤',
#    'authorDisplayName': '@StanSher',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/MznwTvjLDfldwrR60slqStOvuqisCqRL3gxZ4rojIXM19-9-fp5vFtvPiVMu5xapkVtqPSL0=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@StanSher',
#    'authorChannelId': {'value': 'UCOvn1W49BfD59LKS4zBUcxw'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2024-03-15T02:44:59Z',
#    'updatedAt': '2024-03-15T02:44:59Z'},
#   'Comment_published': '2024-03-15T02:44:59Z'},
#  {'Comment_Id': 'UgyE3uvjveEQk0UdJdt4AaABAg',
#   'Video_Id': 'mS6rkYWMVJI',
#   'Comment_text': 'Wow this is serious! Seriously amazing! ❤',
#   'Comment_author': {'channelId': 'UCMwu5UL4nfp7upkIdr0dtWg',
#    'videoId': 'mS6rkYWMVJI',
#    'textDisplay': 'Wow this is serious! Seriously amazing! ❤',
#    'textOriginal': 'Wow this is serious! Seriously amazing! ❤',
#    'authorDisplayName': '@StanSher',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/MznwTvjLDfldwrR60slqStOvuqisCqRL3gxZ4rojIXM19-9-fp5vFtvPiVMu5xapkVtqPSL0=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@StanSher',
#    'authorChannelId': {'value': 'UCOvn1W49BfD59LKS4zBUcxw'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2024-03-15T02:44:59Z',
#    'updatedAt': '2024-03-15T02:44:59Z'},
#   'Comment_published': '2024-03-15T02:44:59Z'},
#  {'Comment_Id': 'UgyE3uvjveEQk0UdJdt4AaABAg',
#   'Video_Id': 'mS6rkYWMVJI',
#   'Comment_text': 'Wow this is serious! Seriously amazing! ❤',
#   'Comment_author': {'channelId': 'UCMwu5UL4nfp7upkIdr0dtWg',
#    'videoId': 'mS6rkYWMVJI',
#    'textDisplay': 'Wow this is serious! Seriously amazing! ❤',
#    'textOriginal': 'Wow this is serious! Seriously amazing! ❤',
#    'authorDisplayName': '@StanSher',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/MznwTvjLDfldwrR60slqStOvuqisCqRL3gxZ4rojIXM19-9-fp5vFtvPiVMu5xapkVtqPSL0=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@StanSher',
#    'authorChannelId': {'value': 'UCOvn1W49BfD59LKS4zBUcxw'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2024-03-15T02:44:59Z',
#    'updatedAt': '2024-03-15T02:44:59Z'},
#   'Comment_published': '2024-03-15T02:44:59Z'},
#  {'Comment_Id': 'UgyE3uvjveEQk0UdJdt4AaABAg',
#   'Video_Id': 'mS6rkYWMVJI',
#   'Comment_text': 'Wow this is serious! Seriously amazing! ❤',
#   'Comment_author': {'channelId': 'UCMwu5UL4nfp7upkIdr0dtWg',
#    'videoId': 'mS6rkYWMVJI',
#    'textDisplay': 'Wow this is serious! Seriously amazing! ❤',
#    'textOriginal': 'Wow this is serious! Seriously amazing! ❤',
#    'authorDisplayName': '@StanSher',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/MznwTvjLDfldwrR60slqStOvuqisCqRL3gxZ4rojIXM19-9-fp5vFtvPiVMu5xapkVtqPSL0=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@StanSher',
#    'authorChannelId': {'value': 'UCOvn1W49BfD59LKS4zBUcxw'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2024-03-15T02:44:59Z',
#    'updatedAt': '2024-03-15T02:44:59Z'},
#   'Comment_published': '2024-03-15T02:44:59Z'},
#  {'Comment_Id': 'UgyE3uvjveEQk0UdJdt4AaABAg',
#   'Video_Id': 'mS6rkYWMVJI',
#   'Comment_text': 'Wow this is serious! Seriously amazing! ❤',
#   'Comment_author': {'channelId': 'UCMwu5UL4nfp7upkIdr0dtWg',
#    'videoId': 'mS6rkYWMVJI',
#    'textDisplay': 'Wow this is serious! Seriously amazing! ❤',
#    'textOriginal': 'Wow this is serious! Seriously amazing! ❤',
#    'authorDisplayName': '@StanSher',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/MznwTvjLDfldwrR60slqStOvuqisCqRL3gxZ4rojIXM19-9-fp5vFtvPiVMu5xapkVtqPSL0=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@StanSher',
#    'authorChannelId': {'value': 'UCOvn1W49BfD59LKS4zBUcxw'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2024-03-15T02:44:59Z',
#    'updatedAt': '2024-03-15T02:44:59Z'},
#   'Comment_published': '2024-03-15T02:44:59Z'},
#  {'Comment_Id': 'UgyE3uvjveEQk0UdJdt4AaABAg',
#   'Video_Id': 'mS6rkYWMVJI',
#   'Comment_text': 'Wow this is serious! Seriously amazing! ❤',
#   'Comment_author': {'channelId': 'UCMwu5UL4nfp7upkIdr0dtWg',
#    'videoId': 'mS6rkYWMVJI',
#    'textDisplay': 'Wow this is serious! Seriously amazing! ❤',
#    'textOriginal': 'Wow this is serious! Seriously amazing! ❤',
#    'authorDisplayName': '@StanSher',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/MznwTvjLDfldwrR60slqStOvuqisCqRL3gxZ4rojIXM19-9-fp5vFtvPiVMu5xapkVtqPSL0=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@StanSher',
#    'authorChannelId': {'value': 'UCOvn1W49BfD59LKS4zBUcxw'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2024-03-15T02:44:59Z',
#    'updatedAt': '2024-03-15T02:44:59Z'},
#   'Comment_published': '2024-03-15T02:44:59Z'},
#  {'Comment_Id': 'UgyE3uvjveEQk0UdJdt4AaABAg',
#   'Video_Id': 'mS6rkYWMVJI',
#   'Comment_text': 'Wow this is serious! Seriously amazing! ❤',
#   'Comment_author': {'channelId': 'UCMwu5UL4nfp7upkIdr0dtWg',
#    'videoId': 'mS6rkYWMVJI',
#    'textDisplay': 'Wow this is serious! Seriously amazing! ❤',
#    'textOriginal': 'Wow this is serious! Seriously amazing! ❤',
#    'authorDisplayName': '@StanSher',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/MznwTvjLDfldwrR60slqStOvuqisCqRL3gxZ4rojIXM19-9-fp5vFtvPiVMu5xapkVtqPSL0=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@StanSher',
#    'authorChannelId': {'value': 'UCOvn1W49BfD59LKS4zBUcxw'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2024-03-15T02:44:59Z',
#    'updatedAt': '2024-03-15T02:44:59Z'},
#   'Comment_published': '2024-03-15T02:44:59Z'},
#  {'Comment_Id': 'UgyE3uvjveEQk0UdJdt4AaABAg',
#   'Video_Id': 'mS6rkYWMVJI',
#   'Comment_text': 'Wow this is serious! Seriously amazing! ❤',
#   'Comment_author': {'channelId': 'UCMwu5UL4nfp7upkIdr0dtWg',
#    'videoId': 'mS6rkYWMVJI',
#    'textDisplay': 'Wow this is serious! Seriously amazing! ❤',
#    'textOriginal': 'Wow this is serious! Seriously amazing! ❤',
#    'authorDisplayName': '@StanSher',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/MznwTvjLDfldwrR60slqStOvuqisCqRL3gxZ4rojIXM19-9-fp5vFtvPiVMu5xapkVtqPSL0=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@StanSher',
#    'authorChannelId': {'value': 'UCOvn1W49BfD59LKS4zBUcxw'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2024-03-15T02:44:59Z',
#    'updatedAt': '2024-03-15T02:44:59Z'},
#   'Comment_published': '2024-03-15T02:44:59Z'},
#  ...]

# %%
def tables():
    try:
        channels_table()
        playlist_table()
        videos_table()
        comment_table()
    except:

          return "Tables Created successfully"

# %%
Tables = tables()

# %%
Tables
# Out:
# 'Tables Created successfully'

# %%
# create function for creating tables



def show_channels_table():
    ch_list = []
    db = client["Youtube_data"]
    coll1 = db["channel_details"]
    for ch_data in coll1.find({},{"_id":0,"channel_information":1}):
        ch_list.append(ch_data["channel_information"])
    channels_table = st.dataframe(ch_list)
    return channels_table

def show_playlists_table():
    pl_list = []
    db = client["Youtube_data"]
    coll1 = db["channels_details"]
    for pl_data in coll1.find({},{"_id":0,"playlist_information":1}):
        for i in range(len(pl_data["playlist_information"])):
            pl_list.append(pl_data["playlist_information"][i])
    playlist_table = st.dataframe(pl_list)
    return playlist_table

def show_videos_table():
    vi_list = []
    db = client["Youtube_data"]
    coll2 = db["channel_details"]
    for vi_data in coll2.find({},{"_id":0,"video_information":1}):
        for i in range(len(vi_data["video_information"])):
            vi_list.append(vi_data["video_information"][i])
    videos_table = st.dataframe(vi_list)
    return videos_table

def show_comments_table():
    com_list = []
    db = client["Youtube_data"]
    coll3 = db["channel_details"]
    for com_data in coll3.find({},{"_id":0,"comment_information":1}):
        for i in range(len(com_data["comment_information"])):
            com_list.append(com_data["comment_information"][i])
    comment_table = st.dataframe(com_list)
    return comment_table

# %%
with st.sidebar:
    st.title(":red[YOUTUBE DATA HARVESTING AND WAREHOUSING]")
    st.header("SKILL USED ")
    st.caption("Python scripting")
    st.caption("Data Collection")
    st.caption("MongoDB")
    st.caption("API Integration")
    st.caption("Data Management Using MongoDB and SQL")

channel_id = st.text_input("Enter the Channel Id here")

# channels = channel_id.split(',')
# channels = [ch.strip() for ch in channels if ch]

if st.button("Collect and Store data"):
    
    ch_ids = []
    db = client["Youtube_data"]
    coll1 = db["channel_details"]
    for ch_data in coll1.find({},{"_id":0,"channel_information":1}):
        ch_ids.append(ch_data["channel_information"]["channel_Id"])

    if channel_id in ch_ids:
        st.success("Channel details of the given channel id: " + channel_id + " already exists")

    else:
        output = channel_details(channel_id)
        st.success(output)

if st.button("Migrate to SQL"):
    display = tables()
    st.success(display)

show_table = st.radio("SELECT THE TABLE FOR VIEW",(":green[channels]",":orange[playlists]",":red[videos]",":blue[comments]"))


if show_table == ":green[channels]":
    show_channels_table()

elif show_table == ":orange[playlists]":
    show_playlists_table()

elif show_table == ":red[videos]":
    show_videos_table()

elif show_table == ":blue[comments]":
    show_comments_table()
# Out:
# 2025-02-04 18:11:49.252 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:49.909
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\viren\AppData\Roaming\Python\Python312\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-02-04 18:11:49.911 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:49.912 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:49.913 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:49.916 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:49.918 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:49.919 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:49.920 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:49.921 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:49.922 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:49.923 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:49.923 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:49.924 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:49.926 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:49.927 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:49.928 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:49.929 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:49.929 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:49.931 Session state does not function when running a script without `streamlit run`
# 2025-02-04 18:11:49.933 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:49.934 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:49.937 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:49.938 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:49.939 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:49.940 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:49.942 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:49.943 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:49.944 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:49.945 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:49.946 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:49.947 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:49.949 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:49.951 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:49.953 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:49.954 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:49.955 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:49.957 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:49.993 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:49.995 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# FOR SQL CONNECTION

mydb = psycopg2.connect(host="localhost",
                            user = "postgres",
                            password = "roomno13",
                            database = "youtube_data",
                            port = "5432")
cursor = mydb.cursor()

question = st.selectbox(
    'Please Select your Question',
    ('1. What are the names of all the videos and their corresponding channels?',
     '2. Which channels have the most number of videos, and how many videos do they have?',
     '3. What are the top 10 most viewed videos and their respective channels?',
     '4. How many comments were made on each video, and what are their corresponding video names?',
     '5. Which videos have the highest number of likes, and what are theircorresponding channel names?',
     '6. What is the total number of likes and dislikes for each video, and what aretheir corresponding video names?',
     '7. What is the total number of views for each channel, and what are their corresponding channel names?',
     '8. What are the names of all the channels that have published videos in the year 2022?',
     '9. What is the average duration of all videos in each channel, and what are their corresponding channel names?',
     '10. Which videos have the highest number of comments, and what are their corresponding channel names?'))



if question == '1. What are the names of all the videos and their corresponding channels':
    query1 = "SELECT title AS videos,channel_name as channelname from videos;"
    cursor.execute(query1)
    mydb.commit()
    t1 = cursor.fetchall()
    df = pd.DataFrame(t1,columns=["video title","channel name"])
    st.write(df)
    


elif question == '2.Which channels have the most number of videos, and how many videos do they have?':
    query2 = "select Channel_Name as Channel Name,Total_Videos as No of Videos from channels order by Total_Videos desc;"
    cursor.execute(query2)
    mydb.commit()
    t2=cursor.fetchall()
    df2 = pd.DataFrame(t2, columns=["Channel Name","No Of Videos"])
    st.write(df2)

elif question == '3.What are the top 10 most viewed videos and their respective channels?':
    query3 = '''select Views as views , Channel_Name as Channel Name,Title as Video Title from videos 
                        where Views is not null order by Views desc limit 10;'''
    cursor.execute(query3)
    mydb.commit()
    t3 = cursor.fetchall()
    df3 = pd.DataFrame(t3, columns = ["views","Channel Name","Video title"])
    st.write(df3)

elif question == '4. How many comments were made on each video, and what are their corresponding video names?':
    query4 = "select Comments as No_comments ,Title as VideoTitle from videos where Comments is not null;"
    cursor.execute(query4)
    mydb.commit()
    t4=cursor.fetchall()
    df4=pd.DataFrame(t4, columns=["No Of Comments", "Video Title"])
    st.write(df4)

elif question == '5. Which videos have the highest number of likes, and what are theircorresponding channel names?':
    query5 = '''select Title as VideoTitle, Channel_Name as ChannelName, Likes as LikesCount from videos 
                       where Likes is not null order by Likes desc;'''
    cursor.execute(query5)
    mydb.commit()
    t5 = cursor.fetchall()
    df5=pd.DataFrame(t5, columns=["video Title","channel Name","like count"])
    st.write(df5)

elif question == '6. What is the total number of likes and dislikes for each video, and what aretheir corresponding video names?':
    query6 = '''select Likes as likeCount,Title as VideoTitle from videos;'''
    cursor.execute(query6)
    mydb.commit()
    t6 = cursor.fetchall()
    df6=pd.DataFrame(t6, columns=["like count","video title"])
    st.write(df6)

elif question == '7. What is the total number of views for each channel, and what are their corresponding channel names?':
    query7 = "select Channel_Name as ChannelName, Views as Channelviews from channels;"
    cursor.execute(query7)
    mydb.commit()
    t7=cursor.fetchall()
    df7=pd.DataFrame(t7, columns=["channel name","total views"])
    st.write(df7)

elif question == '8. What are the names of all the channels that have published videos in the year 2022?':
    query8 = '''select Title as Video_Title, Published_Date as VideoRelease, Channel_Name as ChannelName from videos 
                where extract(year from Published_Date) = 2022;'''
    cursor.execute(query8)
    mydb.commit()
    t8=cursor.fetchall()
    df8=pd.DataFrame(t8,columns=["Name", "Video Publised On", "ChannelName"])
    st.write(df8)

elif question == '9. What is the average duration of all videos in each channel, and what are their corresponding channel names?':
    query9 =  "SELECT Channel_Name as channelname, AVG(Duration) AS average_duration FROM videos GROUP BY Channel_Name;"
    cursor.execute(query9)
    mydb.commit()
    t9=cursor.fetchall()
    df9 = pd.DataFrame(t9, columns=['channel name', 'average_duration'])
    df9

    T9 = []
    for index,row in df9.iterrows():
        channel_title=row["channel name"]
        average_duration=row["average_duration"]
        average_duration_str=str(average_duration)
        T9.append(dict(channeltitle=channel_title,averageduration=average_duration_str))
    df1=pd.DataFrame(T9)
    st.write(df1)

elif question == '10. Which videos have the highest number of comments, and what are their corresponding channel names?':
    query10 = '''select Title as VideoTitle, Channel_Name as ChannelName, Comments as Comments from videos 
                       where Comments is not null order by Comments desc;'''
    cursor.execute(query10)
    mydb.commit()
    t10=cursor.fetchall()
    df10=pd.DataFrame(t10, columns=['Video Title', 'Channel Name', 'NO Of Comments'])
    st.write(df10)
# Out:
# 2025-02-04 18:11:50.303 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:50.304 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:50.305 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:50.307 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:50.308 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 18:11:50.309 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
mydb = psycopg2.connect(host="localhost",
                            user = "postgres",
                            password = "roomno13",
                            database = "youtube_data",
                            port = "5432")
cursor = mydb.cursor()

# if question == '1. What are the names of all the videos and their corresponding channels':
query1 = "SELECT title AS videostitle,channel_name as channelname from videos;"
cursor.execute(query1)
# mydb.commit()
t1 = cursor.fetchall()
df1 = pd.DataFrame(t1,columns=["video title","channel name"])
# st.write(df1)
df1
# Out:
# Empty DataFrame
# Columns: [video title, channel name]
# Index: []

# %%
# elif question == '2.Which channels have the most number of videos, and how many videos do they have?':
mydb = psycopg2.connect(host="localhost",
                            user = "postgres",
                            password = "roomno13",
                            database = "youtube_data",
                            port = "5432")
cursor = mydb.cursor()

query2 = '''select channel_name as channelname,total_videos as novideos from channels order by total_videos desc;'''
cursor.execute(query2)
# mydb.commit()
t2=cursor.fetchall()
if t2:

    df2 = pd.DataFrame(t2, columns=["channel name","no_videos"])
# st.write(pd.DataFrame(t2, columns=["Channel Name","No Of Videos"]))
else:
    print("No data found in the 'channels' table")
    df2 = pd.DataFrame(t2, columns=["channel name","no_videos"])
cursor.close()
mydb.close()
df2
print(t2)
# Out:
# No data found in the 'channels' table
# []

# %%
mydb = psycopg2.connect(host="localhost",
                            user = "postgres",
                            password = "roomno13",
                            database = "youtube_data",
                            port = "5432")
cursor = mydb.cursor()

query3 = '''select Views as views , Channel_Name as channelname,Title as VideoTitle from videos 
                    where Views is not null order by Views desc limit 10;'''
cursor.execute(query3)
mydb.commit()
t3 = cursor.fetchall()
df3 = pd.DataFrame(t3, columns = ["views","Channel Name","Video title"])
df3
# Out:
# Empty DataFrame
# Columns: [views, Channel Name, Video title]
# Index: []

# %%
# How many comments were made on each video, and what are their corresponding video names?
mydb = psycopg2.connect(host="localhost",
                            user = "postgres",
                            password = "roomno13",
                            database = "youtube_data",
                            port = "5432")
cursor = mydb.cursor()


# question == '4. How many comments were made on each video, and what are their corresponding video names?':
query4 = "select Comments as No_comments ,Title as VideoTitle from videos where comments is not null;"
cursor.execute(query4)
mydb.commit()
t4=cursor.fetchall()
df4=pd.DataFrame(t4, columns=["No Of Comments", "Video Title"])
df4
# Out:
# Empty DataFrame
# Columns: [No Of Comments, Video Title]
# Index: []

# %%
mydb = psycopg2.connect(host="localhost",
                            user = "postgres",
                            password = "roomno13",
                            database = "youtube_data",
                            port = "5432")
cursor = mydb.cursor()

query5 = '''select Title as VideoTitle, Channel_Name as ChannelName, Likes as LikesCount from videos 
                where Likes is not null order by Likes desc;'''
cursor.execute(query5)
mydb.commit()
t5 = cursor.fetchall()
df5=pd.DataFrame(t5, columns=["video Title","channel Name","like count"])
df5
# Out:
# Empty DataFrame
# Columns: [video Title, channel Name, like count]
# Index: []

# %%
mydb = psycopg2.connect(host="localhost",
                            user = "postgres",
                            password = "roomno13",
                            database = "youtube_data",
                            port = "5432")
cursor = mydb.cursor()

query6 = '''select Likes as likeCount,Title as VideoTitle from videos;'''
cursor.execute(query6)
mydb.commit()
t6 = cursor.fetchall()
df6=pd.DataFrame(t6, columns=["like count","video title"])
df6
# Out:
# Empty DataFrame
# Columns: [like count, video title]
# Index: []

# %%
mydb = psycopg2.connect(host="localhost",
                            user = "postgres",
                            password = "roomno13",
                            database = "youtube_data",
                            port = "5432")
cursor = mydb.cursor()

query7 = "select channel_Name as Channelname, views as channelviews from channels;"
cursor.execute(query7)
mydb.commit()
t7=cursor.fetchall()
df7=pd.DataFrame(t7, columns=["channel name","total views"])
df7
# Out:
# Empty DataFrame
# Columns: [channel name, total views]
# Index: []

# %%
mydb = psycopg2.connect(host="localhost",
                            user = "postgres",
                            password = "roomno13",
                            database = "youtube_data",
                            port = "5432")
cursor = mydb.cursor()

query8 = '''select Title as video_title, published_date as videorelease, Channel_Name as channelname from videos 
            where extract(year from published_date) = 2022;'''
cursor.execute(query8)
# mydb.commit()
t8=cursor.fetchall()
df8=pd.DataFrame(t8,columns=["videotitle","videorelease","channelname"])
df8
# Out:
# Empty DataFrame
# Columns: [videotitle, videorelease, channelname]
# Index: []

# %%
mydb = psycopg2.connect(host="localhost",
                            user = "postgres",
                            password = "roomno13",
                            database = "youtube_data",
                            port = "5432")
cursor = mydb.cursor()

query9 =  "SELECT Channel_Name as channelname, AVG(Duration) AS average_duration FROM videos GROUP BY Channel_Name;"
cursor.execute(query9)
mydb.commit()
t9=cursor.fetchall()
df9 = pd.DataFrame(t9, columns=['channel name', 'average_duration'])
df9

T9 = []
for index,row in df9.iterrows():
    channel_title=row["channel name"]
    average_duration=row["average_duration"]
    average_duration_str=str(average_duration)
    T9.append(dict(channeltitle=channel_title,averageduration=average_duration_str))
df9=pd.DataFrame(T9)


df9
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
mydb = psycopg2.connect(host="localhost",
                            user = "postgres",
                            password = "roomno13",
                            database = "youtube_data",
                            port = "5432")
cursor = mydb.cursor()

query10 = '''select title as videotitle, channel_name as channelName, comments as comments from videos 
                where comments is not null order by comments desc;'''
cursor.execute(query10)
mydb.commit()
t10=cursor.fetchall()
df10=pd.DataFrame(t10,columns=['Video Title','Channel Name','comments'])
df10
# Out:
# Empty DataFrame
# Columns: [Video Title, Channel Name, comments]
# Index: []

# %%
# mydb = psycopg2.connect(host="localhost",
#                             user = "postgres",
#                             password = "roomno13",
#                             database = "youtube_data",
#                             port = "5432")
# cursor = mydb.cursor()


# query1 = '''SELECT title AS videos, channel_Name AS ChannelName FROM videos'''
# cursor.execute(query1)
# mydb.commit()
# t1 = cursor.fetchall()
# df = pd.DataFrame(t1, columns=["Videos", "ChannelName"])
# df
